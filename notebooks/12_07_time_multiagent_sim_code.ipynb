# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/src/multi_agent_sim")
from multi_agent_sim import MultiAgentSim

# %%
infection_dynamics_params = {
    'forward_gen_alpha': 8,
    'forward_gen_beta_hyperparams': (5,5),
    'detectability_curve_type': 'optimistic',
    'self_reporting_multiplier': 0.8,
    'self_reporting_delay': 3,
    'init_infection_rate': 0.001,
    'use_deterministic_infection_counts': True,
}

social_network_params_high_var = {
    'location_vec_dim': 2,
    'network_gamma': 3,
    'daily_contacts_distn_type': 'negative_binomial',
    'neg_bin_r': 2,
    'neg_bin_p_hyperparams': (2,3),
}

n_agents = 1000
main_params = {
    'n_agents': 1000,
    'use_contact_tracing': False,
    'use_adaptive_testing': True,
    'use_surveillance_testing': True
}

ct_params = {
    'ct_recall_window': 8,
    'ct_delay_distribution': [1/3,1/3,1/3], # uniform over 0, 1, 2 days delay
    'ct_recall_rate': 0.5
}

at_params = {
    'at_delay_distribution': [1/5] * 5,
    'at_net_size_contact_multiplier': 10,
    'at_recall_rate': 0.9
}

st_params = {
    'st_testing_window': 3,
    'st_missed_test_rate': 0.1
}

def init_high_var_sim(R0):
    social_network_params_high_var['neg_bin_r'] = R0 / 0.9
    return MultiAgentSim(main_params, infection_dynamics_params, social_network_params_high_var, 
                         ct_params, at_params, st_params)

social_network_params_low_var = {
    'location_vec_dim': 2,
    'network_gamma': 3,
    'daily_contacts_distn_type': 'negative_binomial',
    'neg_bin_r': 2,
    'neg_bin_p_hyperparams': (5,6),
}

def init_low_var_sim(R0):
    social_network_params_low_var['neg_bin_r'] = R0 / 0.9
    return MultiAgentSim(main_params, infection_dynamics_params, social_network_params_low_var, 
                         ct_params, at_params, st_params)

# %%
def sample_trajectory(R0, at_multiplier, st_testing_window):
    st_params['st_testing_window'] = st_testing_window
    at_params['at_net_size_contact_multiplier'] = at_multiplier
    sim = init_low_var_sim(R0)
    infection_counts = [len(sim.infection.get_cum_infected_agent_ids())]
    init_infection_counts = infection_counts[0]
    for _ in range(7*12):
        sim.step()
        infection_counts.append(len(sim.infection.get_cum_infected_agent_ids()))
    total_tests = sim.get_total_tests()
    return total_tests, infection_counts, init_infection_counts, infection_counts[-1]

# %%
import cProfile
cProfile.run('sample_trajectory(1.5, 2, 7)')
# Out:
#          17780401 function calls (16778868 primitive calls) in 23.288 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       210    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(any)
#       210    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(atleast_1d)
#        39    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(count_nonzero)
#        35    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(cumsum)
#    999000    0.740    0.000    4.040    0.000 <__array_function__ internals>:2(dot)
#       630    0.001    0.000    0.020    0.000 <__array_function__ internals>:2(extract)
#       630    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(nonzero)
#    999000    0.922    0.000   15.542    0.000 <__array_function__ internals>:2(norm)
#       210    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(place)
#      1116    0.001    0.000    0.022    0.000 <__array_function__ internals>:2(prod)
#       210    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(putmask)
#      1260    0.001    0.000    0.008    0.000 <__array_function__ internals>:2(ravel)
#       210    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(shape)
#       630    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(take)
#        35    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(unique)
#         1    0.000    0.000   22.882   22.882 <ipython-input-2-d2b0cf92a8a6>:57(init_low_var_sim)
#         1    0.000    0.000   23.289   23.289 <ipython-input-3-c95aebda872c>:1(sample_trajectory)
#         1    0.001    0.001   23.290   23.290 <string>:1(<module>)
#       210    0.000    0.000    0.000    0.000 <string>:2(_parse_args)
#   1000260    0.346    0.000    0.796    0.000 _asarray.py:16(asarray)
#      1960    0.001    0.000    0.003    0.000 _asarray.py:88(asanyarray)
#       210    0.001    0.000    0.004    0.000 _continuous_distns.py:2555(_pdf)
#       210    0.004    0.000    0.004    0.000 _continuous_distns.py:2559(_logpdf)
#       210    0.011    0.000    0.066    0.000 _distn_infrastructure.py:1694(pdf)
#       210    0.002    0.000    0.030    0.000 _distn_infrastructure.py:520(argsreduce)
#       210    0.004    0.000    0.024    0.000 _distn_infrastructure.py:545(<listcomp>)
#       210    0.002    0.000    0.002    0.000 _distn_infrastructure.py:862(_argcheck)
#       210    0.000    0.000    0.000    0.000 _distn_infrastructure.py:874(_get_support)
#       210    0.001    0.000    0.001    0.000 _distn_infrastructure.py:895(_support_mask)
#       210    0.000    0.000    0.002    0.000 _methods.py:44(_any)
#         5    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         5    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         5    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#         5    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#        13    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#       129    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#         5    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#        61    0.000    0.000    0.001    0.000 abc.py:178(__instancecheck__)
#       5/1    0.000    0.000    0.000    0.000 abc.py:194(__subclasscheck__)
#        22    0.000    0.000    0.023    0.001 adaptive_testing.py:28(trigger_adaptive_test)
#        77    0.000    0.000    0.006    0.000 adaptive_testing.py:3(sample_delay)
#        84    0.000    0.000    0.001    0.000 adaptive_testing.py:46(step_adaptive_tests)
#         1    0.000    0.000    0.000    0.000 adaptive_testing.py:9(__init__)
#   2348034    0.897    0.000    1.330    0.000 agent.py:10(get_param)
#      1000    0.002    0.000    0.002    0.000 agent.py:3(__init__)
#      4126    0.002    0.000    0.002    0.000 agent.py:7(add_param)
#        35    0.000    0.000    0.000    0.000 arraysetops.py:138(_unpack_tuple)
#        35    0.000    0.000    0.000    0.000 arraysetops.py:146(_unique_dispatcher)
#        35    0.000    0.000    0.001    0.000 arraysetops.py:151(unique)
#        35    0.001    0.000    0.001    0.000 arraysetops.py:297(_unique1d)
#         1    0.000    0.000    0.000    0.000 contact_tracing.py:9(__init__)
#         1    0.000    0.000    0.109    0.109 defmatrix.py:117(__new__)
#       184    0.000    0.000    0.000    0.000 defmatrix.py:169(__array_finalize__)
#        61    0.001    0.000    0.002    0.000 defmatrix.py:191(__getitem__)
#        61    0.000    0.000    0.000    0.000 defmatrix.py:937(T)
#      1260    0.000    0.000    0.000    0.000 fromnumeric.py:1644(_ravel_dispatcher)
#      1260    0.002    0.000    0.006    0.000 fromnumeric.py:1648(ravel)
#       630    0.000    0.000    0.000    0.000 fromnumeric.py:1755(_nonzero_dispatcher)
#       630    0.000    0.000    0.002    0.000 fromnumeric.py:1759(nonzero)
#       210    0.000    0.000    0.000    0.000 fromnumeric.py:1852(_shape_dispatcher)
#       210    0.000    0.000    0.000    0.000 fromnumeric.py:1856(shape)
#       210    0.000    0.000    0.000    0.000 fromnumeric.py:2185(_any_dispatcher)
#       210    0.000    0.000    0.004    0.000 fromnumeric.py:2189(any)
#        35    0.000    0.000    0.000    0.000 fromnumeric.py:2354(_cumsum_dispatcher)
#        35    0.000    0.000    0.000    0.000 fromnumeric.py:2358(cumsum)
#      1116    0.000    0.000    0.000    0.000 fromnumeric.py:2787(_prod_dispatcher)
#      1116    0.002    0.000    0.019    0.000 fromnumeric.py:2792(prod)
#      1295    0.001    0.000    0.005    0.000 fromnumeric.py:55(_wrapfunc)
#      1326    0.005    0.000    0.020    0.000 fromnumeric.py:73(_wrapreduction)
#      1326    0.001    0.000    0.001    0.000 fromnumeric.py:74(<dictcomp>)
#       630    0.000    0.000    0.000    0.000 fromnumeric.py:93(_take_dispatcher)
#       630    0.001    0.000    0.004    0.000 fromnumeric.py:97(take)
#       630    0.000    0.000    0.000    0.000 function_base.py:1624(_extract_dispatcher)
#       630    0.002    0.000    0.018    0.000 function_base.py:1628(extract)
#       210    0.000    0.000    0.000    0.000 function_base.py:1680(_place_dispatcher)
#       210    0.000    0.000    0.001    0.000 function_base.py:1684(place)
#      1155    0.002    0.000    0.002    0.000 getlimits.py:365(__new__)
#     10860    0.008    0.000    0.014    0.000 infection_dynamics.py:101(sample_test_result)
#         7    0.000    0.000    0.067    0.010 infection_dynamics.py:115(infect_agent)
#        84    0.000    0.000    0.047    0.001 infection_dynamics.py:132(get_infected_agent_ids)
#        84    0.022    0.000    0.046    0.001 infection_dynamics.py:133(<listcomp>)
#        85    0.000    0.000    0.047    0.001 infection_dynamics.py:138(get_cum_infected_agent_ids)
#        85    0.022    0.000    0.046    0.001 infection_dynamics.py:139(<listcomp>)
#         7    0.001    0.000    0.067    0.010 infection_dynamics.py:17(gen_disc_gamma)
#         7    0.000    0.000    0.000    0.000 infection_dynamics.py:22(<listcomp>)
#         1    0.000    0.000    0.024    0.024 infection_dynamics.py:26(__init__)
#        39    0.000    0.000    0.001    0.000 infection_dynamics.py:61(sample_transmissions)
#        39    0.000    0.000    0.001    0.000 infection_dynamics.py:73(<listcomp>)
#        84    0.001    0.000    0.002    0.000 infection_dynamics.py:76(sample_self_reports)
#        84    0.000    0.000    0.002    0.000 infection_dynamics.py:96(sample_self_report_isolations)
#        84    0.000    0.000    0.000    0.000 infection_dynamics.py:98(<listcomp>)
#    999000    0.345    0.000    0.542    0.000 linalg.py:121(isComplexType)
#    999000    0.159    0.000    0.159    0.000 linalg.py:2321(_norm_dispatcher)
#    999000    6.550    0.000   13.498    0.000 linalg.py:2325(norm)
#         1    0.000    0.000   22.882   22.882 multi_agent_sim.py:11(__init__)
#         1    0.001    0.001    0.003    0.003 multi_agent_sim.py:19(<dictcomp>)
#        84    0.001    0.000    0.360    0.004 multi_agent_sim.py:34(step)
#         1    0.000    0.000    0.000    0.000 multi_agent_sim.py:97(get_total_tests)
#       210    0.000    0.000    0.000    0.000 multiarray.py:1078(putmask)
#    999000    0.150    0.000    0.150    0.000 multiarray.py:707(dot)
#       100    0.000    0.000    0.001    0.000 numeric.py:1782(isscalar)
#        39    0.000    0.000    0.000    0.000 numeric.py:405(_count_nonzero_dispatcher)
#        39    0.000    0.000    0.000    0.000 numeric.py:409(count_nonzero)
#        78    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#        39    0.000    0.000    0.000    0.000 numerictypes.py:365(issubdtype)
#       420    0.003    0.000    0.005    0.000 numerictypes.py:578(_can_coerce_all)
#      2940    0.001    0.000    0.001    0.000 numerictypes.py:587(<listcomp>)
#       210    0.001    0.000    0.006    0.000 numerictypes.py:602(find_common_type)
#       210    0.000    0.000    0.000    0.000 numerictypes.py:654(<listcomp>)
#       210    0.000    0.000    0.000    0.000 numerictypes.py:655(<listcomp>)
#        28    0.000    0.000    0.000    0.000 quarantine_manager.py:11(isolate_agent)
#         7    0.000    0.000    0.000    0.000 quarantine_manager.py:17(free_agent)
#         1    0.000    0.000    0.000    0.000 quarantine_manager.py:2(__init__)
#        84    0.025    0.000    0.050    0.001 quarantine_manager.py:22(step_isolation_removals)
#       222    0.000    0.000    0.000    0.000 quarantine_manager.py:7(is_agent_isolated)
#       210    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#       210    0.001    0.000    0.003    0.000 shape_base.py:24(atleast_1d)
#         1    0.067    0.067   22.775   22.775 social_network.py:10(__init__)
#      1000    0.001    0.000    0.011    0.000 social_network.py:26(<listcomp>)
#      1000    5.820    0.006   22.582    0.023 social_network.py:35(<listcomp>)
#        22    0.000    0.000    0.000    0.000 social_network.py:41(get_mean_contacts)
#        22    0.006    0.000    0.015    0.001 social_network.py:48(get_n_closest_agents)
#        39    0.001    0.000    0.021    0.001 social_network.py:64(sample_contacts)
#        84    0.071    0.001    0.171    0.002 surveillance_testing.py:24(step_surveillance_tests)
#      1000    0.004    0.000    0.076    0.000 surveillance_testing.py:3(sample_delay)
#         1    0.003    0.003    0.080    0.080 surveillance_testing.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55f50df1d020}
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         1    0.000    0.000   23.290   23.290 {built-in method builtins.exec}
#      2626    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#      2089    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
# 1998129/1998120    0.401    0.000    0.401    0.000 {built-in method builtins.issubclass}
#      4900    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#        39    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        22    0.009    0.000    0.009    0.000 {built-in method builtins.sorted}
#        46    0.008    0.000    0.008    0.000 {built-in method builtins.sum}
#        57    0.000    0.000    0.000    0.000 {built-in method math.exp}
#   1003282    0.563    0.000    0.563    0.000 {built-in method numpy.array}
#       210    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath._insert}
#        39    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.count_nonzero}
# 2003425/1001905    4.121    0.000   14.513    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        35    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#       210    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         5    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#         5    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#        10    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       210    0.001    0.000    0.002    0.000 {method 'any' of 'numpy.generic' objects}
#      1202    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        35    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#      1000    0.002    0.000    0.002    0.000 {method 'beta' of 'numpy.random.mtrand.RandomState' objects}
#      1116    0.062    0.000    0.088    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#        35    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        96    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 {method 'gamma' of 'numpy.random.mtrand.RandomState' objects}
#   2349201    0.433    0.000    0.433    0.000 {method 'get' of 'dict' objects}
#      1579    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        39    0.000    0.000    0.000    0.000 {method 'negative_binomial' of 'numpy.random.mtrand.RandomState' objects}
#       630    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#   1000260    1.370    0.000    1.370    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1326    0.011    0.000    0.011    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       630    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       630    0.002    0.000    0.002    0.000 {method 'take' of 'numpy.ndarray' objects}
#        61    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     14402    0.068    0.000    0.068    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}

# %%
main_params['n_agents'] = 3000
cProfile.run('sample_trajectory(1.5, 2, 7)')
# Out:
#          155251235 function calls (146250995 primitive calls) in 200.324 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       270    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(any)
#       270    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(atleast_1d)
#        90    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(count_nonzero)
#       135    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(cumsum)
#   8997000    6.526    0.000   35.373    0.000 <__array_function__ internals>:2(dot)
#       810    0.001    0.000    0.026    0.000 <__array_function__ internals>:2(extract)
#       810    0.001    0.000    0.003    0.000 <__array_function__ internals>:2(nonzero)
#   8997000    8.156    0.000  135.504    0.000 <__array_function__ internals>:2(norm)
#       270    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(place)
#      3141    0.004    0.000    0.060    0.000 <__array_function__ internals>:2(prod)
#       270    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(putmask)
#      1620    0.001    0.000    0.010    0.000 <__array_function__ internals>:2(ravel)
#       270    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(shape)
#       810    0.001    0.000    0.007    0.000 <__array_function__ internals>:2(take)
#       135    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(unique)
#         1    0.000    0.000  199.178  199.178 <ipython-input-2-d2b0cf92a8a6>:57(init_low_var_sim)
#         1    0.000    0.000  200.328  200.328 <ipython-input-3-c95aebda872c>:1(sample_trajectory)
#         1    0.002    0.002  200.330  200.330 <string>:1(<module>)
#       270    0.000    0.000    0.000    0.000 <string>:2(_parse_args)
#   8998620    3.136    0.000    6.887    0.000 _asarray.py:16(asarray)
#      2700    0.001    0.000    0.003    0.000 _asarray.py:88(asanyarray)
#       270    0.001    0.000    0.006    0.000 _continuous_distns.py:2555(_pdf)
#       270    0.005    0.000    0.005    0.000 _continuous_distns.py:2559(_logpdf)
#       270    0.014    0.000    0.085    0.000 _distn_infrastructure.py:1694(pdf)
#       270    0.002    0.000    0.038    0.000 _distn_infrastructure.py:520(argsreduce)
#       270    0.005    0.000    0.031    0.000 _distn_infrastructure.py:545(<listcomp>)
#       270    0.003    0.000    0.003    0.000 _distn_infrastructure.py:862(_argcheck)
#       270    0.000    0.000    0.000    0.000 _distn_infrastructure.py:874(_get_support)
#       270    0.001    0.000    0.001    0.000 _distn_infrastructure.py:895(_support_mask)
#       270    0.000    0.000    0.002    0.000 _methods.py:44(_any)
#       218    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#       109    0.000    0.000    0.001    0.000 abc.py:178(__instancecheck__)
#        19    0.000    0.000    0.047    0.002 adaptive_testing.py:28(trigger_adaptive_test)
#        51    0.000    0.000    0.004    0.000 adaptive_testing.py:3(sample_delay)
#        84    0.000    0.000    0.000    0.000 adaptive_testing.py:46(step_adaptive_tests)
#         1    0.000    0.000    0.000    0.000 adaptive_testing.py:9(__init__)
#  19040343    7.533    0.000   10.972    0.000 agent.py:10(get_param)
#      3000    0.003    0.000    0.003    0.000 agent.py:3(__init__)
#     12103    0.006    0.000    0.006    0.000 agent.py:7(add_param)
#       135    0.000    0.000    0.000    0.000 arraysetops.py:138(_unpack_tuple)
#       135    0.000    0.000    0.000    0.000 arraysetops.py:146(_unique_dispatcher)
#       135    0.000    0.000    0.004    0.000 arraysetops.py:151(unique)
#       135    0.002    0.000    0.003    0.000 arraysetops.py:297(_unique1d)
#         1    0.000    0.000    0.000    0.000 contact_tracing.py:9(__init__)
#         1    0.000    0.000    0.917    0.917 defmatrix.py:117(__new__)
#       328    0.000    0.000    0.000    0.000 defmatrix.py:169(__array_finalize__)
#       109    0.001    0.000    0.002    0.000 defmatrix.py:191(__getitem__)
#       109    0.000    0.000    0.000    0.000 defmatrix.py:937(T)
#      1620    0.000    0.000    0.000    0.000 fromnumeric.py:1644(_ravel_dispatcher)
#      1620    0.002    0.000    0.007    0.000 fromnumeric.py:1648(ravel)
#       810    0.000    0.000    0.000    0.000 fromnumeric.py:1755(_nonzero_dispatcher)
#       810    0.000    0.000    0.002    0.000 fromnumeric.py:1759(nonzero)
#       270    0.000    0.000    0.000    0.000 fromnumeric.py:1852(_shape_dispatcher)
#       270    0.000    0.000    0.000    0.000 fromnumeric.py:1856(shape)
#       270    0.000    0.000    0.000    0.000 fromnumeric.py:2185(_any_dispatcher)
#       270    0.000    0.000    0.004    0.000 fromnumeric.py:2189(any)
#       135    0.000    0.000    0.000    0.000 fromnumeric.py:2354(_cumsum_dispatcher)
#       135    0.000    0.000    0.003    0.000 fromnumeric.py:2358(cumsum)
#      3141    0.001    0.000    0.001    0.000 fromnumeric.py:2787(_prod_dispatcher)
#      3141    0.006    0.000    0.052    0.000 fromnumeric.py:2792(prod)
#      1755    0.001    0.000    0.009    0.000 fromnumeric.py:55(_wrapfunc)
#      3411    0.013    0.000    0.050    0.000 fromnumeric.py:73(_wrapreduction)
#      3411    0.003    0.000    0.003    0.000 fromnumeric.py:74(<dictcomp>)
#       810    0.000    0.000    0.000    0.000 fromnumeric.py:93(_take_dispatcher)
#       810    0.001    0.000    0.006    0.000 fromnumeric.py:97(take)
#       810    0.000    0.000    0.000    0.000 function_base.py:1624(_extract_dispatcher)
#       810    0.003    0.000    0.024    0.000 function_base.py:1628(extract)
#       270    0.000    0.000    0.000    0.000 function_base.py:1680(_place_dispatcher)
#       270    0.000    0.000    0.002    0.000 function_base.py:1684(place)
#      3231    0.005    0.000    0.006    0.000 getlimits.py:365(__new__)
#     32505    0.022    0.000    0.038    0.000 infection_dynamics.py:101(sample_test_result)
#         9    0.000    0.000    0.087    0.010 infection_dynamics.py:115(infect_agent)
#        84    0.000    0.000    0.139    0.002 infection_dynamics.py:132(get_infected_agent_ids)
#        84    0.065    0.001    0.139    0.002 infection_dynamics.py:133(<listcomp>)
#        85    0.000    0.000    0.140    0.002 infection_dynamics.py:138(get_cum_infected_agent_ids)
#        85    0.066    0.001    0.140    0.002 infection_dynamics.py:139(<listcomp>)
#         9    0.001    0.000    0.086    0.010 infection_dynamics.py:17(gen_disc_gamma)
#         9    0.000    0.000    0.000    0.000 infection_dynamics.py:22(<listcomp>)
#         1    0.000    0.000    0.043    0.043 infection_dynamics.py:26(__init__)
#        90    0.000    0.000    0.003    0.000 infection_dynamics.py:61(sample_transmissions)
#        90    0.001    0.000    0.002    0.000 infection_dynamics.py:73(<listcomp>)
#        84    0.001    0.000    0.003    0.000 infection_dynamics.py:76(sample_self_reports)
#        84    0.000    0.000    0.003    0.000 infection_dynamics.py:96(sample_self_report_isolations)
#        84    0.000    0.000    0.000    0.000 infection_dynamics.py:98(<listcomp>)
#   8997000    3.253    0.000    4.966    0.000 linalg.py:121(isComplexType)
#   8997000    1.361    0.000    1.361    0.000 linalg.py:2321(_norm_dispatcher)
#   8997000   56.483    0.000  117.330    0.000 linalg.py:2325(norm)
#         1    0.000    0.000  199.178  199.178 multi_agent_sim.py:11(__init__)
#         1    0.003    0.003    0.007    0.007 multi_agent_sim.py:19(<dictcomp>)
#        84    0.001    0.000    1.009    0.012 multi_agent_sim.py:34(step)
#         1    0.000    0.000    0.000    0.000 multi_agent_sim.py:97(get_total_tests)
#       270    0.000    0.000    0.000    0.000 multiarray.py:1078(putmask)
#   8997000    1.317    0.000    1.317    0.000 multiarray.py:707(dot)
#       199    0.000    0.000    0.001    0.000 numeric.py:1782(isscalar)
#        90    0.000    0.000    0.000    0.000 numeric.py:405(_count_nonzero_dispatcher)
#        90    0.000    0.000    0.000    0.000 numeric.py:409(count_nonzero)
#       180    0.000    0.000    0.000    0.000 numerictypes.py:293(issubclass_)
#        90    0.000    0.000    0.001    0.000 numerictypes.py:365(issubdtype)
#       540    0.004    0.000    0.006    0.000 numerictypes.py:578(_can_coerce_all)
#      3780    0.001    0.000    0.001    0.000 numerictypes.py:587(<listcomp>)
#       270    0.001    0.000    0.007    0.000 numerictypes.py:602(find_common_type)
#       270    0.000    0.000    0.000    0.000 numerictypes.py:654(<listcomp>)
#       270    0.000    0.000    0.000    0.000 numerictypes.py:655(<listcomp>)
#        17    0.000    0.000    0.000    0.000 quarantine_manager.py:11(isolate_agent)
#         8    0.000    0.000    0.000    0.000 quarantine_manager.py:17(free_agent)
#         1    0.000    0.000    0.000    0.000 quarantine_manager.py:2(__init__)
#        84    0.075    0.001    0.150    0.002 quarantine_manager.py:22(step_isolation_removals)
#       281    0.000    0.000    0.000    0.000 quarantine_manager.py:7(is_agent_isolated)
#       270    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#       270    0.001    0.000    0.004    0.000 shape_base.py:24(atleast_1d)
#         1    0.599    0.599  198.890  198.890 social_network.py:10(__init__)
#      3000    0.003    0.000    0.031    0.000 social_network.py:26(<listcomp>)
#      3000   51.174    0.017  197.319    0.066 social_network.py:35(<listcomp>)
#        19    0.000    0.000    0.000    0.000 social_network.py:41(get_mean_contacts)
#        19    0.014    0.001    0.041    0.002 social_network.py:48(get_n_closest_agents)
#        90    0.002    0.000    0.107    0.001 social_network.py:64(sample_contacts)
#        84    0.217    0.003    0.516    0.006 surveillance_testing.py:24(step_surveillance_tests)
#      3000    0.011    0.000    0.226    0.000 surveillance_testing.py:3(sample_delay)
#         1    0.008    0.008    0.238    0.238 surveillance_testing.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55f50df1d020}
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         1    0.000    0.000  200.330  200.330 {built-in method builtins.exec}
#      5166    0.005    0.000    0.005    0.000 {built-in method builtins.getattr}
#      2908    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#  17994270    3.535    0.000    3.535    0.000 {built-in method builtins.issubclass}
#      8085    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#        90    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        19    0.026    0.001    0.026    0.001 {built-in method builtins.sorted}
#        99    0.056    0.001    0.056    0.001 {built-in method builtins.sum}
#        51    0.000    0.000    0.000    0.000 {built-in method math.exp}
#   9004430    4.679    0.000    4.679    0.000 {built-in method numpy.array}
#       270    0.002    0.000    0.002    0.000 {built-in method numpy.core._multiarray_umath._insert}
#        90    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.count_nonzero}
# 18002901/9002661   36.199    0.000  126.089    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       135    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#       270    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       270    0.001    0.000    0.003    0.000 {method 'any' of 'numpy.generic' objects}
#      1377    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       135    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#      3000    0.007    0.000    0.007    0.000 {method 'beta' of 'numpy.random.mtrand.RandomState' objects}
#      3141    0.188    0.000    0.263    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#       135    0.002    0.000    0.002    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       244    0.001    0.000    0.001    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'gamma' of 'numpy.random.mtrand.RandomState' objects}
#  19043586    3.440    0.000    3.440    0.000 {method 'get' of 'dict' objects}
#      3664    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#        90    0.001    0.000    0.001    0.000 {method 'negative_binomial' of 'numpy.random.mtrand.RandomState' objects}
#       810    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#   8998620   11.804    0.000   11.804    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      3411    0.028    0.000    0.028    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       810    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       810    0.004    0.000    0.004    0.000 {method 'take' of 'numpy.ndarray' objects}
#       109    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     42620    0.202    0.000    0.202    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}

# %%
cProfile.run('init_low_var_sim(1.5)')
# Out:
#          153048321 function calls (144049881 primitive calls) in 204.198 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       120    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(any)
#       120    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(atleast_1d)
#   8997000    6.588    0.000   36.486    0.000 <__array_function__ internals>:2(dot)
#       360    0.001    0.000    0.016    0.000 <__array_function__ internals>:2(extract)
#       360    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(nonzero)
#   8997000    8.481    0.000  139.510    0.000 <__array_function__ internals>:2(norm)
#       120    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(place)
#      3000    0.004    0.000    0.057    0.000 <__array_function__ internals>:2(prod)
#       120    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(putmask)
#       720    0.001    0.000    0.006    0.000 <__array_function__ internals>:2(ravel)
#       120    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(shape)
#       360    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(take)
#         1    0.000    0.000  204.201  204.201 <ipython-input-2-d2b0cf92a8a6>:57(init_low_var_sim)
#         1    0.002    0.002  204.203  204.203 <string>:1(<module>)
#       120    0.000    0.000    0.000    0.000 <string>:2(_parse_args)
#   8997720    3.125    0.000    6.991    0.000 _asarray.py:16(asarray)
#      1080    0.000    0.000    0.002    0.000 _asarray.py:88(asanyarray)
#       120    0.000    0.000    0.004    0.000 _continuous_distns.py:2555(_pdf)
#       120    0.004    0.000    0.004    0.000 _continuous_distns.py:2559(_logpdf)
#       120    0.009    0.000    0.054    0.000 _distn_infrastructure.py:1694(pdf)
#       120    0.001    0.000    0.023    0.000 _distn_infrastructure.py:520(argsreduce)
#       120    0.003    0.000    0.020    0.000 _distn_infrastructure.py:545(<listcomp>)
#       120    0.002    0.000    0.002    0.000 _distn_infrastructure.py:862(_argcheck)
#       120    0.000    0.000    0.000    0.000 _distn_infrastructure.py:874(_get_support)
#       120    0.001    0.000    0.001    0.000 _distn_infrastructure.py:895(_support_mask)
#       120    0.000    0.000    0.001    0.000 _methods.py:44(_any)
#         1    0.000    0.000    0.000    0.000 adaptive_testing.py:9(__init__)
#  17994004    7.597    0.000   11.018    0.000 agent.py:10(get_param)
#      3000    0.002    0.000    0.002    0.000 agent.py:3(__init__)
#     12016    0.009    0.000    0.009    0.000 agent.py:7(add_param)
#         1    0.000    0.000    0.000    0.000 contact_tracing.py:9(__init__)
#         1    0.000    0.000    0.920    0.920 defmatrix.py:117(__new__)
#         1    0.000    0.000    0.000    0.000 defmatrix.py:169(__array_finalize__)
#       720    0.000    0.000    0.000    0.000 fromnumeric.py:1644(_ravel_dispatcher)
#       720    0.001    0.000    0.004    0.000 fromnumeric.py:1648(ravel)
#       360    0.000    0.000    0.000    0.000 fromnumeric.py:1755(_nonzero_dispatcher)
#       360    0.000    0.000    0.001    0.000 fromnumeric.py:1759(nonzero)
#       120    0.000    0.000    0.000    0.000 fromnumeric.py:1852(_shape_dispatcher)
#       120    0.000    0.000    0.000    0.000 fromnumeric.py:1856(shape)
#       120    0.000    0.000    0.000    0.000 fromnumeric.py:2185(_any_dispatcher)
#       120    0.000    0.000    0.003    0.000 fromnumeric.py:2189(any)
#      3000    0.001    0.000    0.001    0.000 fromnumeric.py:2787(_prod_dispatcher)
#      3000    0.005    0.000    0.049    0.000 fromnumeric.py:2792(prod)
#       720    0.001    0.000    0.004    0.000 fromnumeric.py:55(_wrapfunc)
#      3120    0.012    0.000    0.046    0.000 fromnumeric.py:73(_wrapreduction)
#      3120    0.002    0.000    0.002    0.000 fromnumeric.py:74(<dictcomp>)
#       360    0.000    0.000    0.000    0.000 fromnumeric.py:93(_take_dispatcher)
#       360    0.001    0.000    0.004    0.000 fromnumeric.py:97(take)
#       360    0.000    0.000    0.000    0.000 function_base.py:1624(_extract_dispatcher)
#       360    0.002    0.000    0.015    0.000 function_base.py:1628(extract)
#       120    0.000    0.000    0.000    0.000 function_base.py:1680(_place_dispatcher)
#       120    0.000    0.000    0.002    0.000 function_base.py:1684(place)
#      3000    0.005    0.000    0.006    0.000 getlimits.py:365(__new__)
#         4    0.000    0.000    0.055    0.014 infection_dynamics.py:115(infect_agent)
#         4    0.001    0.000    0.054    0.014 infection_dynamics.py:17(gen_disc_gamma)
#         4    0.000    0.000    0.000    0.000 infection_dynamics.py:22(<listcomp>)
#         1    0.001    0.001    0.055    0.055 infection_dynamics.py:26(__init__)
#   8997000    3.279    0.000    5.042    0.000 linalg.py:121(isComplexType)
#   8997000    1.488    0.000    1.488    0.000 linalg.py:2321(_norm_dispatcher)
#   8997000   58.342    0.000  120.915    0.000 linalg.py:2325(norm)
#         1    0.000    0.000  204.201  204.201 multi_agent_sim.py:11(__init__)
#         1    0.003    0.003    0.005    0.005 multi_agent_sim.py:19(<dictcomp>)
#       120    0.000    0.000    0.000    0.000 multiarray.py:1078(putmask)
#   8997000    1.296    0.000    1.296    0.000 multiarray.py:707(dot)
#       240    0.003    0.000    0.003    0.000 numerictypes.py:578(_can_coerce_all)
#      1680    0.001    0.000    0.001    0.000 numerictypes.py:587(<listcomp>)
#       120    0.000    0.000    0.004    0.000 numerictypes.py:602(find_common_type)
#       120    0.000    0.000    0.000    0.000 numerictypes.py:654(<listcomp>)
#       120    0.000    0.000    0.000    0.000 numerictypes.py:655(<listcomp>)
#         1    0.000    0.000    0.000    0.000 quarantine_manager.py:2(__init__)
#       120    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#       120    0.001    0.000    0.002    0.000 shape_base.py:24(atleast_1d)
#         1    0.658    0.658  203.900  203.900 social_network.py:10(__init__)
#      3000    0.006    0.000    0.067    0.000 social_network.py:26(<listcomp>)
#      3000   51.686    0.017  202.214    0.067 social_network.py:35(<listcomp>)
#      3000    0.011    0.000    0.228    0.000 surveillance_testing.py:3(sample_delay)
#         1    0.008    0.008    0.240    0.240 surveillance_testing.py:9(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55f50df1d020}
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         1    0.000    0.000  204.203  204.203 {built-in method builtins.exec}
#      3840    0.004    0.000    0.004    0.000 {built-in method builtins.getattr}
#       964    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#  17994000    3.506    0.000    3.506    0.000 {built-in method builtins.issubclass}
#      5042    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#   9001801    4.803    0.000    4.803    0.000 {built-in method numpy.array}
#       120    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath._insert}
# 17999400/9000960   37.236    0.000  129.619    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       120    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       120    0.000    0.000    0.002    0.000 {method 'any' of 'numpy.generic' objects}
#       480    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#      3000    0.015    0.000    0.015    0.000 {method 'beta' of 'numpy.random.mtrand.RandomState' objects}
#      3000    0.153    0.000    0.216    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'gamma' of 'numpy.random.mtrand.RandomState' objects}
#  17997016    3.422    0.000    3.422    0.000 {method 'get' of 'dict' objects}
#      3120    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#       360    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#   8997720   12.313    0.000   12.313    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      3120    0.026    0.000    0.026    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       360    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       360    0.003    0.000    0.003    0.000 {method 'take' of 'numpy.ndarray' objects}
#      6000    0.061    0.000    0.061    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
