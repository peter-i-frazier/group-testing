# %%
schema_csv = """all_positives_complete,id
all_positives_complete,first_name
all_positives_complete,last_name
all_positives_complete,netid
all_positives_complete,employee_id
all_positives_complete,from_ch_pui_list
all_positives_complete,fac_staff
all_positives_complete,supervisory_organization_type
all_positives_complete,unit_code
all_positives_complete,department_code
all_positives_complete,job_family
all_positives_complete,job_profile_name
all_positives_complete,work_space
all_positives_complete,manager_name
all_positives_complete,manager_netid
all_positives_complete,supervisory_organization_type_2
all_positives_complete,unit_code_2
all_positives_complete,department_code_2
all_positives_complete,job_family_2
all_positives_complete,job_profile_name_2
all_positives_complete,worker_status_2
all_positives_complete,work_space_2
all_positives_complete,manager_name_2
all_positives_complete,manager_netid_2
all_positives_complete,academic_career
all_positives_complete,academic_program
all_positives_complete,academic_level
all_positives_complete,gender
all_positives_complete,ethnicity
all_positives_complete,birthdate
all_positives_complete,age
all_positives_complete,greek
all_positives_complete,greek_orgs
all_positives_complete,athlete
all_positives_complete,sports
all_positives_complete,online_only
all_positives_complete,oncampus
all_positives_complete,local_address
all_positives_complete,home_address
all_positives_complete,home_city
all_positives_complete,home_postal
all_positives_complete,county_1
all_positives_complete,county_2
all_positives_complete,county_3
all_positives_complete,confirmation_date
all_positives_complete,tchd_notify_date
all_positives_complete,in_isolation
all_positives_complete,test_site
all_positives_complete,date_tested
all_positives_complete,tested_in_quarantine
all_positives_complete,sample_type
all_positives_complete,ct_value
all_positives_complete,test_reason
all_positives_complete,test_reason_sharon
all_positives_complete,was_a_contact
all_positives_complete,number_of_contacts
all_positives_complete,contacts_tested.ch
all_positives_complete,contacts_positive_ch
all_positives_complete,contacts_positive
all_positives_complete,prop_pos_ch
all_positives_complete,prop_pos
all_positives_complete,exposed_date
all_positives_complete,pcr_test_results
all_positives_complete,cleared_date
all_positives_complete,oncampus_building
all_positives_complete,oncampus_roomtype
all_positives_complete,oncampus_suitedescr
all_positives_complete,oncampus_buildingfloor
all_positives_complete,oncampus_roommates
chs_recent_positives,population
chs_recent_positives,id
chs_recent_positives,account_number
chs_recent_positives,first_name
chs_recent_positives,last_name
chs_recent_positives,dob
chs_recent_positives,netid
chs_recent_positives,email_address
chs_recent_positives,cell_phone
chs_recent_positives,sample_type
chs_recent_positives,collection_date
chs_recent_positives,ver_date
chs_recent_positives,address
chs_recent_positives,zip
chs_recent_positives,reg_city
chs_recent_positives,reg_state
chs_recent_positives,zip_code
chs_recent_positives,registered_Testing_Site
chs_recent_positives,patient_status
chs_recent_positives,cornell_result
chs_recent_positives,test_result
chs_recent_positives,ct_value
chs_recent_positives,routing_provider
chs_recent_positives_ss,population
chs_recent_positives_ss,id
chs_recent_positives_ss,account_number
chs_recent_positives_ss,first_name
chs_recent_positives_ss,last_name
chs_recent_positives_ss,dob
chs_recent_positives_ss,netid
chs_recent_positives_ss,email_address
chs_recent_positives_ss,cell_phone
chs_recent_positives_ss,sample_type
chs_recent_positives_ss,collection_dt
chs_recent_positives_ss,ver_dt
chs_recent_positives_ss,address
chs_recent_positives_ss,zip
chs_recent_positives_ss,reg_city
chs_recent_positives_ss,reg_State
chs_recent_positives_ss,zip_cd
chs_recent_positives_ss,registered_testing_site
chs_recent_positives_ss,patient_status
chs_recent_positives_ss,cornell_result
chs_recent_positives_ss,test_result
chs_recent_positives_ss,ct_value
chs_recent_positives_ss,routing_provider
chs_testing_data_cleaned,booking_status
chs_testing_data_cleaned,booking_time
chs_testing_data_cleaned,id
chs_testing_data_cleaned,dob
chs_testing_data_cleaned,dept
chs_testing_data_cleaned,emplid
chs_testing_data_cleaned,netid
chs_testing_data_cleaned,email_address
chs_testing_data_cleaned,first_name
chs_testing_data_cleaned,last_name
chs_testing_data_cleaned,staff_faculty
chs_testing_data_cleaned,student
chs_testing_data_cleaned,employer_name
chs_testing_data_cleaned,job_code
chs_testing_data_cleaned,job_family_group
chs_testing_data_cleaned,job_family
chs_testing_data_cleaned,job_profile
chs_testing_data_cleaned,location
chs_testing_data_cleaned,meets_criteria_time
chs_testing_data_cleaned,organization_status
chs_testing_data_cleaned,organization_unit
chs_testing_data_cleaned,patient_status
chs_testing_data_cleaned,reg_source_system_patient_id
chs_testing_data_cleaned,reg_source_system_patient_id_old
chs_testing_data_cleaned,sample_type
chs_testing_data_cleaned,sample_dt
chs_testing_data_cleaned,staff_sample_type
chs_testing_data_cleaned,testing_site_id
chs_testing_data_cleaned,testing_site
chs_testing_data_cleaned,unit_college
cleaned_testing_data_from_cmc_latest,booking_status
cleaned_testing_data_from_cmc_latest,booking_time
cleaned_testing_data_from_cmc_latest,dob
cleaned_testing_data_from_cmc_latest,dept
cleaned_testing_data_from_cmc_latest,employee_id
cleaned_testing_data_from_cmc_latest,email_address
cleaned_testing_data_from_cmc_latest,employer_name
cleaned_testing_data_from_cmc_latest,first_name
cleaned_testing_data_from_cmc_latest,id
cleaned_testing_data_from_cmc_latest,job_code
cleaned_testing_data_from_cmc_latest,job_family_group
cleaned_testing_data_from_cmc_latest,job_family
cleaned_testing_data_from_cmc_latest,job_profile_name
cleaned_testing_data_from_cmc_latest,last_name
cleaned_testing_data_from_cmc_latest,location
cleaned_testing_data_from_cmc_latest,meets_criteria_timestamp
cleaned_testing_data_from_cmc_latest,netid
cleaned_testing_data_from_cmc_latest,organization_status
cleaned_testing_data_from_cmc_latest,organization_unit
cleaned_testing_data_from_cmc_latest,patient_status
cleaned_testing_data_from_cmc_latest,registration_source_system_patient_id
cleaned_testing_data_from_cmc_latest,registration_source_system_patient_id_old
cleaned_testing_data_from_cmc_latest,staff_faculty
cleaned_testing_data_from_cmc_latest,student
cleaned_testing_data_from_cmc_latest,sample_type
cleaned_testing_data_from_cmc_latest,sampled_date
cleaned_testing_data_from_cmc_latest,staff_sample_location
cleaned_testing_data_from_cmc_latest,testing_site_id
cleaned_testing_data_from_cmc_latest,testing_site
cleaned_testing_data_from_cmc_latest,unit_college
contact_tracing,patient_name
contact_tracing,employee_id
contact_tracing,netid
contact_tracing,dob
contact_tracing,gender
contact_tracing,age
contact_tracing,academic_level
contact_tracing,school
contact_tracing,grad_prof_ug
contact_tracing,last_semester_attended
contact_tracing,mobil_phone
contact_tracing,local_address_1
contact_tracing,local_address_2
contact_tracing,local_state
contact_tracing,local_city
contact_tracing,local_postal
contact_tracing,number_of_contacts
contact_tracing,exposed_date
contact_tracing,pcr_test_results
contact_tracing,confirmation_date
contact_tracing,cleared_date
contacts_of_covid_patients,source_patient_netid
contacts_of_covid_patients,exposed_patient_netid
contacts_of_covid_patients,dob
contacts_of_covid_patients,gender
contacts_of_covid_patients,age
contacts_of_covid_patients,academic_level
contacts_of_covid_patients,school
contacts_of_covid_patients,grad_prof_ug
contacts_of_covid_patients,last_semester_attended
contacts_of_covid_patients,exposure_location
contacts_of_covid_patients,local_address_1
contacts_of_covid_patients,local_address_2
contacts_of_covid_patients,local_city
contacts_of_covid_patients,local_state
contacts_of_covid_patients,local_postal
contacts_of_covid_patients,athlete
contacts_of_covid_patients,sports
daily_checkin_fc,person_sid
daily_checkin_fc,created_at_date
daily_checkin_fc,updated_at_date
daily_checkin_fc,netid
daily_checkin_fc,email
daily_checkin_fc,name
daily_checkin_fc,id
daily_checkin_fc,job_family_group
daily_checkin_fc,primary_affiliation
daily_checkin_fc,check_in_type
daily_checkin_fc,at_cornell
daily_checkin_fc,cleared
daily_checkin_fc,cmc_cleared
daily_checkin_fc,cleared_contact
daily_checkin_fc,current_flag
daily_checkin_fc,covid_symptoms
daily_checkin_fc,positive_test
daily_checkin_fc,tele_med_visit
daily_checkin_fc,symptoms_worsened
daily_checkin_fc,contact_diagnosed
daily_checkin_fc,contact_symptoms
daily_checkin_fc,contact_telmed_visit
daily_checkin_fc,increased_risk
daily_checkin_fc,follow_guidance
daily_checkin_fc,attested_cleared
daily_checkin_fc,attested_guidance
daily_checkin_fc,covid_status
daily_checkin_fc,status_by_date
daily_checkin_fc,reasons
daily_checkin_fc,first_red_date
daily_checkin_fc,fill_gap_row
daily_checkin_fc,count
daily_checkin_fc,curr_day_flag
daily_checkin_naps,id
daily_checkin_naps,user_id
daily_checkin_naps,emplid
daily_checkin_naps,netid
daily_checkin_naps,name
daily_checkin_naps,email
daily_checkin_naps,exception_type
daily_checkin_naps,status
daily_checkin_naps,status_date
daily_checkin_naps,exception_start_date
daily_checkin_naps,exception_end_date
daily_checkin_naps,created_by_id
daily_checkin_naps,updated_by_id
daily_checkin_naps,created_at_date
daily_checkin_naps,updated_at_date
daily_checkin_naps,deleted_at_date
daily_checkin_naps,surveillancetest_source
daily_checkin_naps,college
daily_checkin_person_dm,person_sid
daily_checkin_person_dm,netid
daily_checkin_person_dm,email
daily_checkin_person_dm,employee_id
daily_checkin_person_dm,name
daily_checkin_person_dm,last_name
daily_checkin_person_dm,first_name
daily_checkin_person_dm,middle_name
daily_checkin_person_dm,pref_name
daily_checkin_person_dm,birthdate
daily_checkin_person_dm,age
daily_checkin_person_dm,gender
daily_checkin_person_dm,ethnicity
daily_checkin_person_dm,st_urm_flag
daily_checkin_person_dm,primary_org_code
daily_checkin_person_dm,primary_unitid
daily_checkin_person_dm,primary_deptid
daily_checkin_person_dm,college_org_name
daily_checkin_person_dm,dept_org_name
daily_checkin_person_dm,cu_primary_affiliation
daily_checkin_person_dm,cu_primary_affiliation_descr
daily_checkin_person_dm,home_address
daily_checkin_person_dm,home_city
daily_checkin_person_dm,home_state
daily_checkin_person_dm,home_postal
daily_checkin_person_dm,home_country
daily_checkin_person_dm,home_phone
daily_checkin_person_dm,campus_address
daily_checkin_person_dm,campus_city
daily_checkin_person_dm,campus_state
daily_checkin_person_dm,campus_postal
daily_checkin_person_dm,campus_phone
daily_checkin_person_dm,student_status
daily_checkin_person_dm,academic_term
daily_checkin_person_dm,academic_term_sdescr
daily_checkin_person_dm,academic_term_ldescr
daily_checkin_person_dm,academic_org
daily_checkin_person_dm,academic_org_sdescr
daily_checkin_person_dm,academic_org_ldescr
daily_checkin_person_dm,level_number
daily_checkin_person_dm,level_indicator
daily_checkin_person_dm,institution
daily_checkin_person_dm,academic_career
daily_checkin_person_dm,academic_career_sdescr
daily_checkin_person_dm,academic_career_ldescr
daily_checkin_person_dm,academic_program
daily_checkin_person_dm,academic_program_sdescr
daily_checkin_person_dm,academic_program_ldescr
daily_checkin_person_dm,academic_plan
daily_checkin_person_dm,academic_plan_sdescr
daily_checkin_person_dm,academic_plan_ldescr
daily_checkin_person_dm,academic_plan_type
daily_checkin_person_dm,primary_jobcode
daily_checkin_person_dm,wd_job_family_group
daily_checkin_person_dm,wd_job_family
daily_checkin_person_dm,wd_job_profile
daily_checkin_person_dm,wd_manager_netid
daily_checkin_person_dm,wd_workplace_location
daily_checkin_surveillance,id
daily_checkin_surveillance,user_id
daily_checkin_surveillance,emplid
daily_checkin_surveillance,netid
daily_checkin_surveillance,name
daily_checkin_surveillance,email
daily_checkin_surveillance,test_date
daily_checkin_surveillance,cmc_test_id
daily_checkin_surveillance,complete_date
daily_checkin_surveillance,missed_test
daily_checkin_surveillance,created_at_date
daily_checkin_surveillance,updated_at_date
daily_checkin_surveillance,surveillancetest_source
daily_checkin_surveillance,college
daily_checklist_fc,name
daily_checklist_fc,netid
daily_checklist_fc,email
daily_checklist_fc,primary_affiliation
daily_checklist_fc,id
daily_checklist_fc,user_id
daily_checklist_fc,where
daily_checklist_fc,roommates
daily_checklist_fc,housemates
daily_checklist_fc,arrival
daily_checklist_fc,arrivaldate
daily_checklist_fc,arrival_date
daily_checklist_fc,arrival_country
daily_checklist_fc,arrival_state
daily_checklist_fc,arrival_method
daily_checklist_fc,self_quarantine
daily_checklist_fc,pre_tested
daily_checklist_fc,drop_off
daily_checklist_fc,unfinal_address
daily_checklist_fc,has_local_contact
daily_checklist_fc,ra_contact
daily_checklist_fc,test_scheduled
daily_checklist_fc,test_scheduled_late
daily_checklist_fc,testdate
daily_checklist_fc,test_date
daily_checklist_fc,step1
daily_checklist_fc,step2
daily_checklist_fc,step3
daily_checklist_fc,step4
daily_checklist_fc,step5
daily_checklist_fc,step6
daily_checklist_fc,step7
daily_checklist_fc,step8
daily_checklist_fc,created_at
daily_checklist_fc,created_at_date
daily_checklist_fc,updated_at
daily_checklist_fc,updated_at_date
irp_pandemic_stdnt_enrl,academic_term
irp_pandemic_stdnt_enrl,academic_term_sdescr
irp_pandemic_stdnt_enrl,employee_id
irp_pandemic_stdnt_enrl,academic_career
irp_pandemic_stdnt_enrl,netid
irp_pandemic_stdnt_enrl,current_primary_first_name
irp_pandemic_stdnt_enrl,current_primary_last_name
irp_pandemic_stdnt_enrl,current_pre_first_name
irp_pandemic_stdnt_enrl,current_pref_last_name
irp_pandemic_stdnt_enrl,birthdate
irp_pandemic_stdnt_enrl,current_gender
irp_pandemic_stdnt_enrl,deceased_flag
irp_pandemic_stdnt_enrl,citizen1_country_ldescr
irp_pandemic_stdnt_enrl,withdraw_code
irp_pandemic_stdnt_enrl,withdraw_date
irp_pandemic_stdnt_enrl,enrolled_flag
irp_pandemic_stdnt_enrl,form_of_study
irp_pandemic_stdnt_enrl,address_type
irp_pandemic_stdnt_enrl,address1
irp_pandemic_stdnt_enrl,address2
irp_pandemic_stdnt_enrl,address3
irp_pandemic_stdnt_enrl,city
irp_pandemic_stdnt_enrl,state
irp_pandemic_stdnt_enrl,state_descr
irp_pandemic_stdnt_enrl,postal
irp_pandemic_stdnt_enrl,county
irp_pandemic_stdnt_enrl,country
irp_pandemic_stdnt_enrl,country_sdescr
irp_pandemic_stdnt_enrl,country_ldescr
irp_pandemic_stdnt_enrl,employee_degree_flag
irp_pandemic_stdnt_enrl,instr_advisor_name
irp_pandemic_stdnt_enrl,instr_advisor_netid
irp_pandemic_stdnt_enrl,college
irp_pandemic_stdnt_enrl,admit_type_concat
irp_pandemic_stdnt_enrl,admit_term
irp_pandemic_stdnt_enrl,admit_term_sdescr
irp_pandemic_stdnt_enrl,face_to_face_instruction_flag
irp_pandemic_stdnt_enrl,academic_program1
irp_pandemic_stdnt_enrl,academic_program1_ldescr
irp_pandemic_stdnt_enrl,academic_plan1
irp_pandemic_stdnt_enrl,academic_plan1_ldescr
irp_pandemic_stdnt_enrl,academic_program2
irp_pandemic_stdnt_enrl,academic_program2_ldescr
irp_pandemic_stdnt_enrl,academic_plan2
irp_pandemic_stdnt_enrl,academic_plan2_ldescr
irp_pandemic_stdnt_enrl,academic_program3
irp_pandemic_stdnt_enrl,academic_program3_ldescr
irp_pandemic_stdnt_enrl,academic_plan3
irp_pandemic_stdnt_enrl,academic_plan3_ldescr
irp_pandemic_stdnt_enrl,academic_program4
irp_pandemic_stdnt_enrl,academic_program4_ldescr
irp_pandemic_stdnt_enrl,academic_plan4
irp_pandemic_stdnt_enrl,academic_plan4_ldescr
redcap_positives_official,case_number
redcap_positives_official,redcap_data_access_group
redcap_positives_official,reviewed
redcap_positives_official,nys_tally
redcap_positives_official,exclude_yes
redcap_positives_official,hd_notify_date
redcap_positives_official,cluster_id
redcap_positives_official,test_date
redcap_positives_official,test_id
redcap_positives_official,first_name
redcap_positives_official,last_name
redcap_positives_official,netid
redcap_positives_official,employee_id
redcap_positives_official,dob
redcap_positives_official,test_site
redcap_positives_official,sample_type
redcap_positives_official,ct_value
redcap_positives_official,test_reason
redcap_positives_official,test_reason_sharon
redcap_positives_official,exposed_date
redcap_positives_official,fac_staff
redcap_positives_official,employee01
redcap_positives_official,job_profile_name
redcap_positives_official,notes
redcap_positives_official,ch_pui
redcap_positives_official,symptomatic
redcap_positives_official,positive_covid_cases_cornell_ithaca_complete
redcap_positives_official_b,case_number
redcap_positives_official_b,redcap_data_access_group
redcap_positives_official_b,reviewed
redcap_positives_official_b,nys_tally
redcap_positives_official_b,exclude_yes
redcap_positives_official_b,hd_notify_date
redcap_positives_official_b,cluster_id
redcap_positives_official_b,test_date
redcap_positives_official_b,test_id
redcap_positives_official_b,first_name
redcap_positives_official_b,last_name
redcap_positives_official_b,netid
redcap_positives_official_b,employee_id
redcap_positives_official_b,dob
redcap_positives_official_b,test_site
redcap_positives_official_b,sample_type
redcap_positives_official_b,ct_value
redcap_positives_official_b,test_reason
redcap_positives_official_b,test_reason_sharon
redcap_positives_official_b,exposed_date
redcap_positives_official_b,fac_staff
redcap_positives_official_b,employee01
redcap_positives_official_b,job_profile_name
redcap_positives_official_b,notes
redcap_positives_official_b,ch_pui
redcap_positives_official_b,symptomatic
redcap_positives_official_b,positive_covid_cases_cornell_ithaca_complete
sf_quarantine_isolation,case_number
sf_quarantine_isolation,netid
sf_quarantine_isolation,status
sf_quarantine_isolation,closed_date
sf_quarantine_isolation,created_date
sf_quarantine_isolation,actual_days_in_quarantine
sf_quarantine_isolation,expected_days_in_quarantine
sf_quarantine_isolation,hotel
sf_quarantine_isolation,location
sf_quarantine_isolation,q_i
sf_quarantine_isolation,wellness_status
sf_test_exemptions,case_number
sf_test_exemptions,description
sf_test_exemptions,netid
sf_test_exemptions,start_date
sf_test_exemptions,end_date
sf_test_exemptions,Original_Test_Level
sf_test_exemptions,Override_State
sf_test_exemptions,Override_Test_Level
sf_travel_test_exemptions,case_number
sf_travel_test_exemptions,netid
sf_travel_test_exemptions,current_test_level
sf_travel_test_exemptions,requested_testing_level
sf_travel_test_exemptions,source
sf_travel_test_exemptions,travel_start_date
sf_travel_test_exemptions,travel_end_date
sf_travel_test_exemptions,quarantine_start_date
sf_travel_test_exemptions,quarantine_end_date
sf_travel_test_exemptions,travel_state
testing_data_clean,testing_site
testing_data_clean,testing_date
testing_data_clean,dob
testing_data_clean,employee_id
testing_data_clean,email_address
testing_data_clean,testing_program
testing_data_clean,test_id
testing_data_clean,netid
testing_data_clean,staff_faculty
testing_data_clean,student
testing_data_clean,sample_type
workforce_trend,Concat Emplid Posid
workforce_trend,Employee ID
workforce_trend,Position ID
workforce_trend,Netid
workforce_trend,Preferred Name First Name
workforce_trend,Preferred Name Last Name
workforce_trend,Primary Job
workforce_trend,Job Code
workforce_trend,Job Profile Name
workforce_trend,Job Family
workforce_trend,Job Family Group
workforce_trend,Supervisory Organization
workforce_trend,Department Code
workforce_trend,Unit Code
workforce_trend,Manager
workforce_trend,Manager Employee ID
workforce_trend,Manager Net ID
workforce_trend,Primary Work Address City
workforce_trend,Primary Work Address Postal
workforce_trend,Primary Work Address State
workforce_trend,PrimaryWorkAddressLine1
workforce_trend,PrimaryWorkAddressLine2
workforce_trend,Primary Home Address
workforce_trend,Primary Home Address City
workforce_trend,Primary Home Address Postal Code
workforce_trend,Primary Home Address State
workforce_trend,Dateof Birth
workforce_trend,Citizenship USA Status
workforce_trend,Gender
workforce_trend,Ethnicityfor Reporting
workforce_trend,Effectivedate
"""

# %%
import pprint
schema = {}
for line in schema_csv.split('\n'):
    if ',' not in line:
        continue
    table, col = line.split(',')
    if table not in schema:
        schema[table] = []
    schema[table].append(col)

skip_tables = ['workforce_trend', 'irp_pandemic_stdnt_enrl']
    
cols = set()
for table in schema:
    if table in skip_tables:
        continue
    cols = cols.union(schema[table])
pprint.pprint(sorted(cols))
# Out:
# ['Original_Test_Level',
#  'Override_State',
#  'Override_Test_Level',
#  'academic_career',
#  'academic_career_ldescr',
#  'academic_career_sdescr',
#  'academic_level',
#  'academic_org',
#  'academic_org_ldescr',
#  'academic_org_sdescr',
#  'academic_plan',
#  'academic_plan_ldescr',
#  'academic_plan_sdescr',
#  'academic_plan_type',
#  'academic_program',
#  'academic_program_ldescr',
#  'academic_program_sdescr',
#  'academic_term',
#  'academic_term_ldescr',
#  'academic_term_sdescr',
#  'account_number',
#  'actual_days_in_quarantine',
#  'address',
#  'age',
#  'arrival',
#  'arrival_country',
#  'arrival_date',
#  'arrival_method',
#  'arrival_state',
#  'arrivaldate',
#  'at_cornell',
#  'athlete',
#  'attested_cleared',
#  'attested_guidance',
#  'birthdate',
#  'booking_status',
#  'booking_time',
#  'campus_address',
#  'campus_city',
#  'campus_phone',
#  'campus_postal',
#  'campus_state',
#  'case_number',
#  'cell_phone',
#  'ch_pui',
#  'check_in_type',
# ...

# %%
col_transformations = {
    #'Original_Test_Level',
 #'Override_State',
 #'Override_Test_Level',
 #'academic_career',
 #'academic_career_ldescr',
 #'academic_career_sdescr',
 #'academic_level',
 #'academic_org',
 #'academic_org_ldescr',
 #'academic_org_sdescr',
 #'academic_plan',
 #'academic_plan_ldescr',
 #'academic_plan_sdescr',
 #'academic_plan_type',
 #'academic_program',
 #'academic_program_ldescr',
 #'academic_program_sdescr',
 #'academic_term',
 #'academic_term_ldescr',
 #'academic_term_sdescr',
 #'account_number',
 #'actual_days_in_quarantine',
 'address': 'skip',
 #'age',
 #'arrival',
 #'arrival_country',
 #'arrival_date',
 #'arrival_method',
 #'arrival_state',
 #'arrivaldate',
 #'at_cornell',
 #'athlete',
 #'attested_cleared',
 #'attested_guidance',
 'birthdate': 'year(birthdate) as dob_year',
 #'booking_status',
 #'booking_time',
 'campus_address': 'skip',
 #'campus_city'
 'campus_phone': 'skip',
 #'campus_postal',
 #'campus_state',
 #'case_number',
 'cell_phone': 'skip',
 #'ch_pui',
 #'check_in_type',
 #'cleared',
 #'cleared_contact',
 #'cleared_date',
 #'closed_date',
 #'cluster_id',
 #'cmc_cleared',
 #'cmc_test_id',
 #'collection_date',
 #'collection_dt',
 #'college',
 #'college_org_name',
 #'complete_date',
 #'confirmation_date',
 #'contact_diagnosed',
 #'contact_symptoms',
 #'contact_telmed_visit',
 #'contacts_positive',
 #'contacts_positive_ch',
 'contacts_tested.ch': 'unsure',
 #'cornell_result',
 #'count',
 #'county_1',
 #'county_2',
 #'county_3',
 #'covid_status',
 #'covid_symptoms',
 #'created_at',
 #'created_at_date',
 #'created_by_id',
 #'created_date',
 #'ct_value',
 'cu_primary_affiliation': 'unsure',
 'cu_primary_affiliation_descr': 'unsure',
 #'curr_day_flag',
 #'current_flag',
 #'current_test_level',
 #'date_tested',
 #'deleted_at_date',
 #'department_code',
 #'department_code_2',
 #'dept',
 #'dept_org_name',
 #'description',
 'dob': 'year(dob) as dob_year',
 #'drop_off',
 'email': 'skip',
 'email_address': 'skip',
 'emplid': "HASHBYTES('MD5', CAST(emplid as varchar)) as emplid_id_hash",
 'employee01': 'unsure',
 'employee_id': "HASHBYTES('MD5', CAST(emplid as varchar)) as emplid_id_hash",
 'employer_name': 'unsure',
 #'end_date',
 'ethnicity': 'unsure',
 #'exception_end_date',
 #'exception_start_date',
 #'exception_type',
 #'exclude_yes',
 #'expected_days_in_quarantine',
 #'exposed_date',
 'exposed_patient_netid': "HASHBYTES('MD5', CAST(lower(exposed_patient_netid) as varchar)) as exposed_patient_netid_hash",
 'exposure_location': 'unsure',
 #'fac_staff',
 #'fill_gap_row',
 'first_name': 'skip',
 #'first_red_date',
 #'follow_guidance',
 #'from_ch_pui_list',
 #'gender',
 #'grad_prof_ug',
 #'greek',
 'greek_orgs': 'unsure',
 #'has_local_contact',
 #'hd_notify_date',
 'home_address': 'skip',
 'home_city': 'skip',
 'home_country': 'unsure',
 'home_phone': 'skip',
 'home_postal': 'unsure',
 'home_state': 'unsure',
 #'hotel',
 #'housemates',
 'id': "hashbytes('md5', cast(id as varchar)) as id_hash",
 #'in_isolation',
 #'increased_risk',
 #'institution',
 'job_code': 'unsure',
 'job_family': 'unsure',
 'job_family_2': 'unsure',
 'job_family_group': 'unsure',
 'job_profile': 'unsure',
 'job_profile_name': 'unsure',
 'job_profile_name_2': 'unsure',
 'last_name': 'skip',
 #'last_semester_attended',
 #'level_indicator',
 #'level_number',
 'local_address': 'skip',
 'local_address_1': 'skip',
 'local_address_2': 'skip',
 'local_city': 'unsure',
 'local_postal': 'unsure',
 'local_state': 'unsure',
 'location': 'unsure',
 'manager_name': 'skip',
 'manager_name_2': 'skip',
 'manager_netid': 'skip',
 'manager_netid_2': 'skip',
 #'meets_criteria_time',
 #'meets_criteria_timestamp',
 'middle_name': 'skip',
 #'missed_test',
 'mobil_phone': 'skip',
 #'name',
 'netid': "HASHBYTES('MD5', CAST(lower(netid) as varchar)) as netid_hash",
 #'notes',
 #'number_of_contacts',
 #'nys_tally',
 #'oncampus',
 'oncampus_building': 'unsure',
 'oncampus_buildingfloor': 'unsure',
 'oncampus_roommates': 'unsure',
 'oncampus_roomtype': 'unsure',
 'oncampus_suitedescr': 'unsure',
 'online_only': 'unsure',
 'organization_status': 'unsure',
 'organization_unit': 'unsure',
 'patient_name': 'skip',
 #'patient_status',
 #'pcr_test_results',
 'person_sid': "hashbytes('md5', cast(person_sid as varchar)) as person_sid_hash",
 #'population',
 #'positive_covid_cases_cornell_ithaca_complete',
 #'positive_test',
 #'pre_tested',
 'pref_name': 'skip',
 'primary_affiliation': 'unsure',
 'primary_deptid': 'unsure',
 'primary_jobcode': 'unsure',
 'primary_org_code': 'unsure',
 'primary_unitid': 'unsure',
 #'prop_pos',
 #'prop_pos_ch',
 #'q_i',
 #'quarantine_end_date',
 #'quarantine_start_date',
 'ra_contact': 'skip',
 #'reasons',
 #'redcap_data_access_group',
 'reg_State': 'unsure',
 'reg_city': 'unsure',
 'reg_source_system_patient_id': 'unsure',
 'reg_source_system_patient_id_old': 'unsure',
 'reg_state': 'unsure',
 #'registered_Testing_Site',
 #'registered_testing_site',
 #'registration_source_system_patient_id',
 #'registration_source_system_patient_id_old',
 #'requested_testing_level',
 #'reviewed',
 'roommates': 'unsure',
 #'routing_provider',
 #'sample_dt',
 #'sample_type',
 #'sampled_date',
 #'school',
 #'self_quarantine',
 'source': 'unsure',
 'source_patient_netid': "hasbytes('md5', lower(source_patient_netid)) as source_patient_netid_hash",
 'sports': 'unsure',
 #'st_urm_flag',
 #'staff_faculty',
 #'staff_sample_location',
 #'staff_sample_type',
 #'start_date',
 #'status',
 #'status_by_date',
 #'status_date',
 #'step1',
 #'step2',
 #'step3',
 #'step4',
 #'step5',
 #'step6',
 #'step7',
 #'step8',
 #'student',
 #'student_status',
 'supervisory_organization_type': 'unsure',
 'supervisory_organization_type_2': 'unsure',
 #'surveillancetest_source',
 #'symptomatic',
 #'symptoms_worsened',
 #'tchd_notify_date',
 #'tele_med_visit',
 #'test_date',
 #'test_id',
 #'test_reason',
 #'test_reason_sharon',
 #'test_result',
 #'test_scheduled',
 #'test_scheduled_late',
 #'test_site',
 #'testdate',
 #'tested_in_quarantine',
 #'testing_date',
 #'testing_program',
 #'testing_site',
 #'testing_site_id',
 #'travel_end_date',
 #'travel_start_date',
 #'travel_state',
 'unfinal_address': 'skip',
 #'unit_code',
 #'unit_code_2',
 'unit_college': 'unsure',
 #'updated_at',
 #'updated_at_date',
 'updated_by_id': 'unsure',
 'user_id': "hashbytes('md5', cast(lower(user_id) as varchar)) as user_id_hash",
 #'ver_date',
 #'ver_dt',
 #'was_a_contact',
 #'wd_job_family',
 #'wd_job_family_group',
 #'wd_job_profile',
 'wd_manager_netid': 'skip',
 'wd_workplace_location': 'unsure',
 #'wellness_status',
 'where': 'unsure',
 'work_space': 'unsure',
 'work_space_2': 'unsure',
 'worker_status_2': 'unsure',
 'zip': 'unsure',
 'zip_cd': 'unsure',
 'zip_code': 'unsure'}

# %%
unsures = []
skipped = []
for col, transform in col_transformations.items():
    if transform == 'unsure':
        unsures.append(col)
    elif transform == 'skip':
        skipped.append(col)

print("unsures:\n" + "\n".join(unsures))

print("\nskipped:\n" + "\n".join(skipped))
# Out:
# unsures:
# contacts_tested.ch
# cu_primary_affiliation
# cu_primary_affiliation_descr
# employee01
# employer_name
# ethnicity
# exposure_location
# greek_orgs
# home_country
# home_postal
# home_state
# job_code
# job_family
# job_family_2
# job_family_group
# job_profile
# job_profile_name
# job_profile_name_2
# local_city
# local_postal
# local_state
# location
# oncampus_building
# oncampus_buildingfloor
# oncampus_roommates
# oncampus_roomtype
# oncampus_suitedescr
# online_only
# organization_status
# organization_unit
# primary_affiliation
# primary_deptid
# primary_jobcode
# primary_org_code
# primary_unitid
# reg_State
# reg_city
# reg_source_system_patient_id
# reg_source_system_patient_id_old
# reg_state
# roommates
# source
# sports
# supervisory_organization_type
# supervisory_organization_type_2
# unit_college
# updated_by_id
# wd_workplace_location
# where
# work_space
# work_space_2
# worker_status_2
# zip
# zip_cd
# zip_code
#
# skipped:
# address
# campus_address
# ...

# %%
for table in schema:
    if table in skip_tables:
        continue
    unsure_cols = []
    skipped_cols = []
    included_cols = []
    for col in schema[table]:
        if col in col_transformations:
            reason = col_transformations[col]
            if reason == 'unsure':
                unsure_cols.append(col)
                included_cols.append(col)
            elif reason == 'skip':
                skipped_cols.append(col)
            else:
                included_cols.append(reason)
        else:
            included_cols.append(col)
    
    query = "select {} from {}".format(",\n".join(included_cols), table)
    print(query)
    print("\nFor table {}, skipped columns: {}".format(table, skipped_cols))
    print("\nFor table {}, unsure about columns: {}\n\n\n".format(table, unsure_cols))
# Out:
# select hashbytes('md5', cast(id as varchar)) as id_hash,
# HASHBYTES('MD5', CAST(lower(netid) as varchar)) as netid_hash,
# HASHBYTES('MD5', CAST(emplid as varchar)) as emplid_id_hash,
# from_ch_pui_list,
# fac_staff,
# supervisory_organization_type,
# unit_code,
# department_code,
# job_family,
# job_profile_name,
# work_space,
# supervisory_organization_type_2,
# unit_code_2,
# department_code_2,
# job_family_2,
# job_profile_name_2,
# worker_status_2,
# work_space_2,
# academic_career,
# academic_program,
# academic_level,
# gender,
# ethnicity,
# year(birthdate) as dob_year,
# age,
# greek,
# greek_orgs,
# athlete,
# sports,
# online_only,
# oncampus,
# home_postal,
# county_1,
# county_2,
# county_3,
# confirmation_date,
# tchd_notify_date,
# in_isolation,
# test_site,
# date_tested,
# tested_in_quarantine,
# sample_type,
# ct_value,
# test_reason,
# test_reason_sharon,
# was_a_contact,
# number_of_contacts,
# contacts_tested.ch,
# contacts_positive_ch,
# contacts_positive,
# ...

# %%
schema['irp_pandemic_stdnt_enrl']
# Out:
# ['academic_term',
#  'academic_term_sdescr',
#  'employee_id',
#  'academic_career',
#  'netid',
#  'current_primary_first_name',
#  'current_primary_last_name',
#  'current_pre_first_name',
#  'current_pref_last_name',
#  'birthdate',
#  'current_gender',
#  'deceased_flag',
#  'citizen1_country_ldescr',
#  'withdraw_code',
#  'withdraw_date',
#  'enrolled_flag',
#  'form_of_study',
#  'address_type',
#  'address1',
#  'address2',
#  'address3',
#  'city',
#  'state',
#  'state_descr',
#  'postal',
#  'county',
#  'country',
#  'country_sdescr',
#  'country_ldescr',
#  'employee_degree_flag',
#  'instr_advisor_name',
#  'instr_advisor_netid',
#  'college',
#  'admit_type_concat',
#  'admit_term',
#  'admit_term_sdescr',
#  'face_to_face_instruction_flag',
#  'academic_program1',
#  'academic_program1_ldescr',
#  'academic_plan1',
#  'academic_plan1_ldescr',
#  'academic_program2',
#  'academic_program2_ldescr',
#  'academic_plan2',
#  'academic_plan2_ldescr',
# ...
