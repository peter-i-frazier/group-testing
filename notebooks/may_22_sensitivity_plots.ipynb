# %%
sim_dirs_ls_output = """daily_contacts_fall_realistic.1590118314.26
mild_self_reporting_fall_slightly_pessimistic_testing.1590118314.25
daily_contacts_fall_slightly_pessimistic.1590118314.26
daily_contacts_fall_slightly_optimistic.1590118314.26
daily_contacts_fall_slightly_optimistic_testing.1590118314.25
mild_self_reporting_fall_realistic.1590118314.26
daily_contacts_fall_slightly_pessimistic_testing.1590118314.26
daily_contacts_fall_realistic_testing.1590118314.25
mild_self_reporting_fall_slightly_optimistic_testing.1590118314.25
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 21 23:31 mild_self_reporting_fall_slightly_pessimistic.1590118314.25
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 contact_recall_fall_realistic.1590118314.26
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 21 23:31 mild_self_reporting_fall_slightly_optimistic.1590118314.25
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 21 23:31 mild_self_reporting_fall_realistic_testing.1590118314.25
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 prevalence_fall_slightly_optimistic_testing.1590118314.25
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 prevalence_fall_slightly_optimistic.1590118314.26
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 contact_recall_fall_slightly_optimistic.1590118314.26
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 contact_recall_fall_realistic_testing.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 exposed_infection_p_fall_slightly_optimistic.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 severe_self_reporting_fall_realistic.1590118314.26
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 contact_recall_fall_slightly_pessimistic.1590118314.26
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 exposed_infection_p_fall_slightly_pessimistic.1590118314.26
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 exposed_infection_p_fall_slightly_pessimistic_testing.1590118314.26
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 prevalence_fall_realistic.1590118314.26
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 contact_recall_fall_slightly_pessimistic_testing.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 exposed_infection_p_fall_realistic_testing.1590118314.26
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 prevalence_fall_realistic_testing.1590118314.26
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 severe_self_reporting_fall_realistic_testing.1590118314.26
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 severe_self_reporting_fall_slightly_pessimistic_testing.1590118314.25
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 prevalence_fall_slightly_pessimistic_testing.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 severe_self_reporting_fall_slightly_optimistic_testing.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 severe_self_reporting_fall_slightly_pessimistic.1590118314.26
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 prevalence_fall_slightly_pessimistic.1590118314.25
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 21 23:31 contact_recall_fall_slightly_optimistic_testing.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 exposed_infection_p_fall_realistic.1590118314.26
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 21 23:31 contact_delay_fall_realistic.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 exposed_infection_p_fall_slightly_optimistic_testing.1590118314.25
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 21 23:31 severe_self_reporting_fall_slightly_optimistic.1590118314.25
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 21 23:31 contact_delay_fall_slightly_optimistic_testing.1590118314.26
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 21 23:31 contact_delay_fall_realistic_testing.1590118314.25
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 21 23:31 contact_delay_fall_slightly_pessimistic_testing.1590118314.26
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 21 23:31 contact_delay_fall_slightly_optimistic.1590118314.25
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 21 23:31 contact_delay_fall_slightly_pessimistic.1590118314.25""".split('\n')
sim_dirs = [ls_output.split(' ')[-1] for ls_output in sim_dirs_ls_output]
for d in sim_dirs:
    print(d)
# Out:
# daily_contacts_fall_realistic.1590118314.26
# mild_self_reporting_fall_slightly_pessimistic_testing.1590118314.25
# daily_contacts_fall_slightly_pessimistic.1590118314.26
# daily_contacts_fall_slightly_optimistic.1590118314.26
# daily_contacts_fall_slightly_optimistic_testing.1590118314.25
# mild_self_reporting_fall_realistic.1590118314.26
# daily_contacts_fall_slightly_pessimistic_testing.1590118314.26
# daily_contacts_fall_realistic_testing.1590118314.25
# mild_self_reporting_fall_slightly_optimistic_testing.1590118314.25
# mild_self_reporting_fall_slightly_pessimistic.1590118314.25
# contact_recall_fall_realistic.1590118314.26
# mild_self_reporting_fall_slightly_optimistic.1590118314.25
# mild_self_reporting_fall_realistic_testing.1590118314.25
# prevalence_fall_slightly_optimistic_testing.1590118314.25
# prevalence_fall_slightly_optimistic.1590118314.26
# contact_recall_fall_slightly_optimistic.1590118314.26
# contact_recall_fall_realistic_testing.1590118314.25
# ...

# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/src/simulations_v2")

from analysis_helpers import poisson_waiting_function, \
                            run_multiple_trajectories, \
                            plot_aip_vs_t, \
                            plot_cip_vs_t, \
                            run_sensitivity_sims, \
                            extract_cips, \
                            load_sim_dir

# %%
sim_results = {}
for d in sim_dirs:
    if 'fall_slightly_pessimistic_testing' in d:
        label = 'fall_slightly_pessimistic_testing'
    elif 'fall_slightly_optimistic_testing' in d:
        label = 'fall_slightly_optimistic_testing'
    elif 'fall_realistic_testing' in d:
        label = 'fall_realistic_testing'
    elif 'fall_slightly_pessimistic' in d:
        label = 'fall_slightly_pessimistic'
    elif 'fall_slightly_optimistic' in d:
        label = 'fall_slightly_optimistic'
    elif 'fall_realistic' in d:
        label = 'fall_realistic'
    else:
        print("could not find label for {}".format(d))
        label = 'unlabeled'
    
    sublabel = d.split('_' + label)[0]
    
    if label not in sim_results:
        sim_results[label] = {}
    
    sim_results[label][sublabel] = load_sim_dir("/nfs01/covid_sims/" + d, verbose=False)
    print("done loading {}".format(d))
# Out:
# done loading daily_contacts_fall_realistic.1590118314.26
# done loading mild_self_reporting_fall_slightly_pessimistic_testing.1590118314.25
# done loading daily_contacts_fall_slightly_pessimistic.1590118314.26
# done loading daily_contacts_fall_slightly_optimistic.1590118314.26
# done loading daily_contacts_fall_slightly_optimistic_testing.1590118314.25
# done loading mild_self_reporting_fall_realistic.1590118314.26
# done loading daily_contacts_fall_slightly_pessimistic_testing.1590118314.26
# done loading daily_contacts_fall_realistic_testing.1590118314.25
# done loading mild_self_reporting_fall_slightly_optimistic_testing.1590118314.25
# done loading mild_self_reporting_fall_slightly_pessimistic.1590118314.25
# done loading contact_recall_fall_realistic.1590118314.26
# done loading mild_self_reporting_fall_slightly_optimistic.1590118314.25
# done loading mild_self_reporting_fall_realistic_testing.1590118314.25
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import ticker
# %matplotlib inline
def extract_severities(dfs):
    severities = []
    for df in dfs:
        all_cols = set(df.columns)
        new_cols = set(['cumulative_mild', 
                        'cumulative_severe', 
                        'severity_0', 
                        'severity_1', 
                        'severity_2', 
                        'severity_3'])
        main_cols = all_cols - new_cols
        subdf = df[list(main_cols)]
        popsize = sum(subdf.iloc[0])
        
        subdf = df[['severity_2', 'severity_3']]
        severe = sum(subdf.iloc[subdf.shape[0]-1])
        
        severities.append(100 * severe / popsize)
    return severities
def average_cumulative_severe(dfs):
    severities = []
    for df in dfs:
        all_cols = set(df.columns)
        new_cols = set(['cumulative_mild', 
                        'cumulative_severe', 
                        'severity_0', 
                        'severity_1', 
                        'severity_2', 
                        'severity_3'])
        main_cols = all_cols - new_cols
        subdf = df[list(main_cols)]
        popsize = sum(subdf.iloc[0])
        
        subdf = df[['severity_2', 'severity_3']]
        severe = sum(subdf.iloc[subdf.shape[0]-1])
        
        severities.append(100 * severe / popsize)
    return np.mean(severities)

def avg_cum_severe_quantile(dfs, q_low, q_high):
    severities = extract_severities(dfs)
    return np.quantile(severities, q_low), np.mean(severities), np.quantile(severities, q_high)

def cum_severe_quantiles(dfs, q_low, q_high):
    severities = extract_severities(dfs)
    return np.quantile(severities, q_low), np.quantile(severities, 0.5), np.quantile(severities, q_high)

def plot_many_dfs(sim_output_dict, yaxisfn, ylabel="", xlabel="", title="", figsize=(10,6)):
    plt.figure(figsize=figsize)
    for sim_label, sim_output in sim_output_dict.items():
        xs = []
        ys = []
        for sim_parameter_name, dfs in sim_output.items():
            # compute x-value assuming that sim_param_name is of form 'varied_param_name.value'
            param_val = float('.'.join(sim_parameter_name.split('.')[1:]))
            xs.append(param_val)
            # yaxisfn is a function that takes in a list of trajectory dataframes and
            # produces an output metric
            ys.append(yaxisfn(dfs))
        plt.plot(xs, ys, marker='o', label=sim_label)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend(loc='best')
    plt.show()


def truncate(val, y_min, y_max):
    return max(min(val, y_max), y_min)
    
def plot_many_dfs_quantiles(sim_output_dict, yaxisfn, normalize_x_axis, x_log_scale=False, 
                            y_log_scale=False,
                            q_low=0.05, q_high=0.95, 
                            y_min = 0, y_max = 5,
                            ylabel="", xlabel="", title="", figsize=(10,6), alpha=0.1, color=None, savefig_name = None):
    # assn: yaxisfn(dfs) returns a tuple (q_low_val, avg, q_high_val)
    epsilon=1e-6
    plt.figure(figsize=figsize)
    if x_log_scale:
        plt.xscale("log")
    if y_log_scale:
        plt.yscale("log")
        #_, _, ymin, _ = plt.axis()
        #plt.ylim(bottom=max(1e-2, ymin))
    else:
        plt.ylim(y_min, y_max)
    
    for sim_label, sim_output in sim_output_dict.items():
        xs = []
        ys = []
        q_low_vals = []
        q_high_vals = []
        for sim_parameter_name, dfs in sim_output.items():
            # compute x-value assuming that sim_param_name is of form 'varied_param_name.value'
            param_val = float('.'.join(sim_parameter_name.split('.')[1:]))
            if normalize_x_axis:
                xs.append(param_val * 100)
            else:
                xs.append(param_val)
            # yaxisfn is a function that takes in a list of trajectory dataframes and
            # produces an output metric
            q_low_val, avg, q_high_val = yaxisfn(dfs, q_low, q_high)
            if not y_log_scale:
                ys.append(truncate(avg, y_min, y_max))
                q_low_vals.append(truncate(q_low_val, y_min, y_max))
                q_high_vals.append(truncate(q_high_val, y_min, y_max))
            else:
                ys.append(avg + epsilon)
                q_low_vals.append(q_low_val + epsilon)
                q_high_vals.append(q_high_val + epsilon)
        if color == None:
            plt.plot(xs, ys, marker='o', label=sim_label)
            plt.fill_between(xs, q_low_vals, q_high_vals, alpha=alpha)
        else:
            plt.plot(xs, ys, marker='o', label=sim_label, color=color)
            plt.fill_between(xs, q_low_vals, q_high_vals, alpha=alpha, color=color)
    
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend(loc='best')
    if savefig_name:
        plt.savefig("/nfs01/covid_figs/" + savefig_name + ".pdf")
    
    
    
    plt.show()

# %%
sim_results.keys()
# Out:
# dict_keys(['fall_realistic', 'fall_slightly_pessimistic_testing', 'fall_slightly_pessimistic', 'fall_slightly_optimistic', 'fall_slightly_optimistic_testing', 'fall_realistic_testing'])

# %%
sim_results['fall_realistic'].keys()
# Out:
# dict_keys(['daily_contacts', 'mild_self_reporting', 'contact_recall', 'severe_self_reporting', 'prevalence', 'exposed_infection_p', 'contact_delay'])

# %%
main_labels = sim_results.keys()
sub_labels = sim_results['fall_realistic'].keys()

# %%
plot_labels = {
    'daily_contacts': 'Average Contacts per Person per Day',
    'severe_self_reporting': 'Daily Symptomatic Self-Reporting Likelihoo (%)',
    'prevalence': 'Initial Prevalence (% of Total Population)',
    'mild_self_reporting': 'Daily Asymptomatic Self-Reporting Likelihood(%)',
    'exposed_infection_p': 'Transmission Likelihood per Contact (%)',
    'contact_recall': 'Percentage of Contacts Recalled in Contact Trace (%)',
    'contact_delay': 'Contact Trace Delay (Days)'
}

normalize_params = {
    'daily_contacts': False,
    'severe_self_reporting': True,
    'prevalence': True,
    'mild_self_reporting': True,
    'exposed_infection_p': True,
    'contact_recall': True,
    'contact_delay': False
}

plot_log_scale = {
    'daily_contacts': False,
    'severe_self_reporting': False,
    'prevalence': True,
    'mild_self_reporting': False,
    'exposed_infection_p': False,
    'contact_recall': False,
    'contact_delay': False    
}

# %% [markdown]
# # make plots for 'realistic' parameters

# %%
no_testing_results = sim_results['fall_realistic']
testing_results = sim_results['fall_realistic_testing']

for sublabel in sub_labels:
    
    plot_many_dfs_quantiles({'Without Testing': no_testing_results[sublabel], 
                             'With Testing': testing_results[sublabel]}, 
                            cum_severe_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Hospitalized",
                     title="Realistic Parameters: Hospitalization Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.2, y_min = 0, y_max=5, y_log_scale=True)

# %% [markdown]
# # make plots for 'slightly optimistic' parameters

# %%
no_testing_results = sim_results['fall_slightly_optimistic']
testing_results = sim_results['fall_slightly_optimistic_testing']

for sublabel in sub_labels:
    
    plot_many_dfs_quantiles({'Without Testing': no_testing_results[sublabel], 
                             'With Testing': testing_results[sublabel]}, 
                            cum_severe_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Hospitalized",
                     title="Slightly Optimistic Parameters: Hospitalization Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.2, y_min = 0, y_max=5, y_log_scale=True)

# %% [markdown]
# # and finally, plots for 'slightly pessimistic' parameters

# %%
no_testing_results = sim_results['fall_slightly_pessimistic']
testing_results = sim_results['fall_slightly_pessimistic_testing']

for sublabel in sub_labels:
    
    plot_many_dfs_quantiles({'Without Testing': no_testing_results[sublabel], 
                             'With Testing': testing_results[sublabel]}, 
                            cum_severe_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Hospitalized",
                     title="Slightly Optimistic Parameters: Hospitalization Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.2, y_min = 0, y_max=5, y_log_scale=True)
