# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/src/simulations_v2")

from analysis_helpers import run_multiple_trajectories
from load_params import load_params

# %%
scn_name, params = load_params("../src/simulations_v2/params/fall_reopen_infections_config.yaml")

# %%
dfs = run_multiple_trajectories(params, ntrajectories=100, time_horizon=7)

# %%
from analysis_helpers import plot_aip_vs_t, plot_cip_vs_t

# %%
plot_aip_vs_t(dfs)

# %%
plot_cip_vs_t(dfs)
