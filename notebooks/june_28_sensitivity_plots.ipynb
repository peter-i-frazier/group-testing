# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/src/simulations_v2")

# %%
from multiparam_output_loader import MultiParamOutputLoader
sim_output = MultiParamOutputLoader("/nfs01/covid_sims/1593278033-multiparam")

# %%
sim_output.sim_results.keys()
# Out:
# dict_keys(['Nominal Parameters'])

# %%
sim_output.sim_results['Nominal Parameters'][(10.0, 0.5)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7e6244f25df6> in <module>()
# ----> 1 sim_output.sim_results['Nominal Parameters'][(10.0, 0.5)].keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
sim_results = {'Nominal Parameters': {(x,): data for (x,y), data in sim_output.sim_results['Nominal Parameters'].items() if y == 0.5}}

# %%
sim_results['Nominal Parameters'].keys()
# Out:
# dict_keys([10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0])

# %%
# %run /home/jmc678/covid_data/group-testing/src/simulations_v2/plotting_util.py

# %%
sim_output.varying_params
# Out:
# ['expected_contacts_per_day', 'test_population_fraction']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plot_from_sim_results(sim_results, 'expected_contacts_per_day')

# %%
sim_results = {'Nominal Parameters 1-day testing': {(x,): data for (x,y), data in sim_output.sim_results['Nominal Parameters'].items() if y == 1.0},
              'Nominal Parameters 2-day testing': {(x,): data for (x,y), data in sim_output.sim_results['Nominal Parameters'].items() if y == 0.5},}

# %%
plot_from_sim_results(sim_results, 'expected_contacts_per_day')
