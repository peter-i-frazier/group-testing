# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/src/multi_agent_sim")
from multi_agent_sim import MultiAgentSim

# %%
social_network_params_high_var = {
    'location_vec_dim': 2,
    'network_gamma': 3,
    'daily_contacts_distn_type': 'negative_binomial',
    'neg_bin_r': 2,
    'neg_bin_p_hyperparams': (2,3),
}

n_agents = 1000
expected_total_outside_infs = 5
time_horizon = 7 * 12
main_params = {
    'n_agents': n_agents,
    'use_contact_tracing': True,
    'use_adaptive_testing': True,
    'use_surveillance_testing': True
}

infection_dynamics_params = {
    'forward_gen_alpha': 8,
    'forward_gen_beta_hyperparams': (5,5),
    'detectability_curve_type': 'optimistic',
    'self_reporting_multiplier': 0.8,
    'self_reporting_delay': 3,
    'init_infection_rate': 0,
    'use_deterministic_infection_counts': True,
    'disc_gamma_transmission_mult': 1
    'outside_infection_rate': expected_total_outside_infs / (n_agents * time_horizon)
}

ct_params = {
    'ct_recall_window': 8,
    'ct_delay_distribution': [1/3,1/3,1/3], # uniform over 0, 1, 2 days delay
    'ct_recall_rate': 0.5
}

at_params = {
    'at_delay_distribution': [1/5] * 5,
    'at_net_size_contact_multiplier': 10,
    'at_recall_rate': 0.9
}

st_params = {
    'st_testing_window': 3,
    'st_missed_test_rate': 0.1
}

def init_high_var_sim(R0):
    social_network_params_high_var['neg_bin_r'] = R0 / 0.9
    return MultiAgentSim(main_params, infection_dynamics_params, social_network_params_high_var, 
                         ct_params, at_params, st_params)

social_network_params_low_var = {
    'location_vec_dim': 2,
    'network_gamma': 3,
    'daily_contacts_distn_type': 'negative_binomial',
    'neg_bin_r': 2,
    'neg_bin_p_hyperparams': (5,6),
}

#  r * (alpha) / (beta - 1) = 1 = default R0

def init_low_var_sim(R0):
    social_network_params_low_var['disc_gamma_transmission_mult'] = R0 
    return MultiAgentSim(main_params, infection_dynamics_params, social_network_params_low_var, 
                         ct_params, at_params, st_params)

# %%
social_network_params_high_var = {
    'location_vec_dim': 2,
    'network_gamma': 3,
    'daily_contacts_distn_type': 'negative_binomial',
    'neg_bin_r': 2,
    'neg_bin_p_hyperparams': (2,3),
}

n_agents = 1000
expected_total_outside_infs = 5
time_horizon = 7 * 12
main_params = {
    'n_agents': n_agents,
    'use_contact_tracing': True,
    'use_adaptive_testing': True,
    'use_surveillance_testing': True
}


infection_dynamics_params = {
    'forward_gen_alpha': 8,
    'forward_gen_beta_hyperparams': (5,5),
    'detectability_curve_type': 'optimistic',
    'self_reporting_multiplier': 0.8,
    'self_reporting_delay': 3,
    'init_infection_rate': 0,
    'use_deterministic_infection_counts': True,
    'disc_gamma_transmission_mult': 1,
    'outside_infection_rate': expected_total_outside_infs / (n_agents * time_horizon)
}

ct_params = {
    'ct_recall_window': 4,
    'ct_delay_distribution': [1/3,1/3,1/3], # uniform over 0, 1, 2 days delay
    'ct_recall_rate': 0.5,
    'min_delay_between_traces': 14
}

at_params = {
    'at_delay_distribution': [1/3,1/3,1/3],
    'at_net_size_contact_multiplier': 10,
    'at_recall_rate': 0.9
}

st_params = {
    'st_testing_window': 3,
    'st_missed_test_rate': 0.1
}

def init_high_var_sim(R0):
    social_network_params_high_var['neg_bin_r'] = R0 / 0.9
    return MultiAgentSim(main_params, infection_dynamics_params, social_network_params_high_var, 
                         ct_params, at_params, st_params)

neg_bin_r = 2
social_network_params_low_var = {
    'location_vec_dim': 2,
    'network_gamma': 3,
    'daily_contacts_distn_type': 'negative_binomial',
    'neg_bin_r': neg_bin_r,
    'neg_bin_p_hyperparams': (5,6)
}

# avg close contacts / day = 2 * 5 / (6-1)

def init_low_var_sim(R0):
    social_network_params_low_var['disc_gamma_transmission_mult'] = R0 / neg_bin_r
    return MultiAgentSim(main_params, infection_dynamics_params, social_network_params_low_var, 
                         ct_params, at_params, st_params)

# %%
def sample_trajectory(R0, at_multiplier, st_testing_window, 
                      use_adaptive_testing = True, use_surveillance_testing = True):
    st_params['st_testing_window'] = st_testing_window
    at_params['at_net_size_contact_multiplier'] = at_multiplier
    main_params['use_adaptive_testing'] = use_adaptive_testing
    main_params['use_surveillance_testing'] = use_surveillance_testing
    sim = init_low_var_sim(R0)
    infection_counts = [len(sim.infection.get_cum_infected_agent_ids())]
    init_infection_counts = infection_counts[0]
    for _ in range(time_horizon):
        sim.step()
        infection_counts.append(len(sim.infection.get_cum_infected_agent_ids()))
    total_tests = sim.get_total_tests()
    return total_tests, infection_counts, init_infection_counts, infection_counts[-1]

# %%
from multiprocessing import Process
import pickle


def sim_target_f(R0, at_mult, st_window, use_at, use_st, ntrajectories, pickle_file_loc):
    results = [sample_trajectory(R0, at_mult, st_window, use_at, use_st) for _ in range(ntrajectories)]
    pickle.dump(results, open(pickle_file_loc, "wb"))

def run_sims_new_process(R0, at_mult, st_window, use_at, use_st, ntrajectories, pickle_file_loc):
    p = Process(target = sim_target_f, args = (R0, at_mult, st_window, use_at, use_st, ntrajectories, pickle_file_loc))
    p.start()
    return p

# %%
R0s_to_try = [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]

at_mults = [4,8,12,16]

st_freqs = [4,7,10,14, 18, 21]

adaptive_test_policies = []

surveillance_test_policies = []

no_use = 1

for st_freq in st_freqs:
    surveillance_test_policies.append((no_use, st_freq, False, True))
    for at_mult in at_mults:
        adaptive_test_policies.append((at_mult, st_freq, True, True))
        

ntrajectories = 250

sim_ps = {}

from datetime import datetime

all_policies = adaptive_test_policies + surveillance_test_policies

output_dir = "jan_05_multiagent_sims/"

for R0 in R0s_to_try:
    print("on R0 {}\n".format(R0))
    for policy in all_policies:
        at_mult, st_window, use_at, use_st = policy
        print("on policy {}\n".format(policy))
        print("Timestamp: {}\n".format(datetime.now()))
        sim_ps[(R0, policy)] = run_sims_new_process(R0, at_mult, st_window, 
                                                    use_at, use_st, ntrajectories, 
                                                    output_dir + str((R0, policy)) + ".pickle")
    
print("launched {} processes".format(sim_ps.values()))
for p in sim_ps.values():
    p.join()
# Out:
# on R0 1
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:03.791786
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:03.811086
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:03.818907
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:03.827410
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:03.834658
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:03.841408
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:03.847713
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:03.852947
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:03.859117
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:03.865734
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:03.871914
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:03.878113
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:03.883701
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:03.890247
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:03.895796
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:03.902677
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:03.909142
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:03.915432
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:03.921836
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:03.927915
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:03.934259
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:03.939608
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:03.946253
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:03.952428
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:03.958757
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:03.964782
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:03.971049
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:03.976570
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:03.982882
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:03.989599
#
# on R0 1.5
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:03.996371
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.002327
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.008622
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.014861
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.021272
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.027605
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.036177
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.044115
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.052503
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.062039
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.071020
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.080696
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.089673
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.098699
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.107383
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.117189
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.126709
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.135682
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.144798
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.153866
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.162727
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.172635
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.181550
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.191753
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:04.199886
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:04.210637
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:04.218771
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:04.228012
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:04.238900
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:04.247055
#
# on R0 2
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.256860
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.265783
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.275423
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.283859
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.292753
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.302157
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.311198
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.320073
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.329336
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.338150
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.347416
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.356857
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.365967
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.375012
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.384372
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.393776
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.403079
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.412648
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.422035
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.430824
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.449834
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.468617
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.477580
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.494616
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:04.507602
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:04.516720
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:04.541423
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:04.550079
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:04.559692
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:04.569314
#
# on R0 2.5
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.579423
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.589024
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.598507
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.608126
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.617595
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.627033
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.636685
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:04.646466
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.670957
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.681797
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.694076
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:04.703728
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.714764
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.725317
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.735247
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:04.745240
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.755902
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.766013
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.775588
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:04.785376
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.795282
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.810064
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.819267
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:04.851327
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:04.861545
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:04.895771
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:04.906980
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:04.921517
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:04.939313
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:04.951280
#
# on R0 3
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.962913
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.973057
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.986931
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:04.997554
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.021935
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.033437
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.043292
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.053207
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.065102
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.073102
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.123145
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.132994
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.143576
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.154424
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.163847
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.191609
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.214501
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.228238
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.239050
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.250425
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.261735
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.286609
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.306976
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.346527
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:05.359239
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:05.370901
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:05.381697
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:05.398038
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:05.408920
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:05.421043
#
# on R0 3.5
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:05.431852
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:05.442762
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:05.452649
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:05.477603
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.492329
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.504278
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.516169
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:05.526576
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.537393
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.576048
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.615336
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:05.626238
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.647756
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.668994
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.689951
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:05.723563
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.741867
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.756987
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.772177
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:05.789525
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.820145
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.831934
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.845831
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:05.860366
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:05.875607
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:05.907409
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:05.919092
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:05.943780
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:05.954707
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:05.979011
#
# on R0 4
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:05.991937
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:06.006780
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:06.017810
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:06.034655
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.048878
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.063137
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.077489
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.094976
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.108376
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.154877
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.191643
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.225876
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:06.251049
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:06.277642
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:06.297075
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:06.324024
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:06.335485
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:06.371808
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:06.387777
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:06.399232
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:06.410377
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:06.424598
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:06.443814
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:06.455523
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:06.466805
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:06.479523
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:06.492447
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:06.520718
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:06.567958
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:06.585348
#
# on R0 4.5
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:06.601800
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:06.618962
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:06.675961
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:06.719314
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.763815
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.781199
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.796255
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:06.811583
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.826695
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.841716
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.867710
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:06.904127
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:06.935859
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:06.952208
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:06.975855
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:07.005269
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.031232
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.063811
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.087337
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.105263
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.120649
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.148551
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.161712
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.196119
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:07.214562
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:07.243949
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:07.256860
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:07.270954
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:07.284576
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:07.299101
#
# on R0 5
#
# on policy (4, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:07.317373
#
# on policy (8, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:07.359746
#
# on policy (12, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:07.384629
#
# on policy (16, 4, True, True)
#
# Timestamp: 2021-01-05 22:45:07.416674
#
# on policy (4, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:07.463390
#
# on policy (8, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:07.491385
#
# on policy (12, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:07.508333
#
# on policy (16, 7, True, True)
#
# Timestamp: 2021-01-05 22:45:07.555320
#
# on policy (4, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:07.588676
#
# on policy (8, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:07.599863
#
# on policy (12, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:07.647800
#
# on policy (16, 10, True, True)
#
# Timestamp: 2021-01-05 22:45:07.678250
#
# on policy (4, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:07.704304
#
# on policy (8, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:07.743418
#
# on policy (12, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:07.792677
#
# on policy (16, 14, True, True)
#
# Timestamp: 2021-01-05 22:45:07.805633
#
# on policy (4, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.817708
#
# on policy (8, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.863098
#
# on policy (12, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.879858
#
# on policy (16, 18, True, True)
#
# Timestamp: 2021-01-05 22:45:07.893030
#
# on policy (4, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.911041
#
# on policy (8, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.928512
#
# on policy (12, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.947423
#
# on policy (16, 21, True, True)
#
# Timestamp: 2021-01-05 22:45:07.966883
#
# on policy (1, 4, False, True)
#
# Timestamp: 2021-01-05 22:45:07.986973
#
# on policy (1, 7, False, True)
#
# Timestamp: 2021-01-05 22:45:08.002005
#
# on policy (1, 10, False, True)
#
# Timestamp: 2021-01-05 22:45:08.019380
#
# on policy (1, 14, False, True)
#
# Timestamp: 2021-01-05 22:45:08.047439
#
# on policy (1, 18, False, True)
#
# Timestamp: 2021-01-05 22:45:08.065776
#
# on policy (1, 21, False, True)
#
# Timestamp: 2021-01-05 22:45:08.089915
# launched dict_values([<Process(Process-1, started)>, <Process(Process-2, started)>, <Process(Process-3, started)>, <Process(Process-4, started)>, <Process(Process-5, started)>, <Process(Process-6, started)>, <Process(Process-7, started)>, <Process(Process-8, started)>, <Process(Process-9, started)>, <Process(Process-10, started)>, <Process(Process-11, started)>, <Process(Process-12, started)>, <Process(Process-13, started)>, <Process(Process-14, started)>, <Process(Process-15, started)>, <Process(Process-16, started)>, <Process(Process-17, started)>, <Process(Process-18, started)>, <Process(Process-19, started)>, <Process(Process-20, started)>, <Process(Process-21, started)>, <Process(Process-22, started)>, <Process(Process-23, started)>, <Process(Process-24, started)>, <Process(Process-25, started)>, <Process(Process-26, started)>, <Process(Process-27, started)>, <Process(Process-28, started)>, <Process(Process-29, started)>, <Process(Process-30, started)>, <Process(Process-31, started)>, <Process(Process-32, started)>, <Process(Process-33, started)>, <Process(Process-34, started)>, <Process(Process-35, started)>, <Process(Process-36, started)>, <Process(Process-37, started)>, <Process(Process-38, started)>, <Process(Process-39, started)>, <Process(Process-40, started)>, <Process(Process-41, started)>, <Process(Process-42, started)>, <Process(Process-43, started)>, <Process(Process-44, started)>, <Process(Process-45, started)>, <Process(Process-46, started)>, <Process(Process-47, started)>, <Process(Process-48, started)>, <Process(Process-49, started)>, <Process(Process-50, started)>, <Process(Process-51, started)>, <Process(Process-52, started)>, <Process(Process-53, started)>, <Process(Process-54, started)>, <Process(Process-55, started)>, <Process(Process-56, started)>, <Process(Process-57, started)>, <Process(Process-58, started)>, <Process(Process-59, started)>, <Process(Process-60, started)>, <Process(Process-61, started)>, <Process(Process-62, started)>, <Process(Process-63, started)>, <Process(Process-64, started)>, <Process(Process-65, started)>, <Process(Process-66, started)>, <Process(Process-67, started)>, <Process(Process-68, started)>, <Process(Process-69, started)>, <Process(Process-70, started)>, <Process(Process-71, started)>, <Process(Process-72, started)>, <Process(Process-73, started)>, <Process(Process-74, started)>, <Process(Process-75, started)>, <Process(Process-76, started)>, <Process(Process-77, started)>, <Process(Process-78, started)>, <Process(Process-79, started)>, <Process(Process-80, started)>, <Process(Process-81, started)>, <Process(Process-82, started)>, <Process(Process-83, started)>, <Process(Process-84, started)>, <Process(Process-85, started)>, <Process(Process-86, started)>, <Process(Process-87, started)>, <Process(Process-88, started)>, <Process(Process-89, started)>, <Process(Process-90, started)>, <Process(Process-91, started)>, <Process(Process-92, started)>, <Process(Process-93, started)>, <Process(Process-94, started)>, <Process(Process-95, started)>, <Process(Process-96, started)>, <Process(Process-97, started)>, <Process(Process-98, started)>, <Process(Process-99, started)>, <Process(Process-100, started)>, <Process(Process-101, started)>, <Process(Process-102, started)>, <Process(Process-103, started)>, <Process(Process-104, started)>, <Process(Process-105, started)>, <Process(Process-106, started)>, <Process(Process-107, started)>, <Process(Process-108, started)>, <Process(Process-109, started)>, <Process(Process-110, started)>, <Process(Process-111, started)>, <Process(Process-112, started)>, <Process(Process-113, started)>, <Process(Process-114, started)>, <Process(Process-115, started)>, <Process(Process-116, started)>, <Process(Process-117, started)>, <Process(Process-118, started)>, <Process(Process-119, started)>, <Process(Process-120, started)>, <Process(Process-121, started)>, <Process(Process-122, started)>, <Process(Process-123, started)>, <Process(Process-124, start ...
