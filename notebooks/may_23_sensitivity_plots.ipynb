# %%
sim_dirs_ls_output = """daily_contacts_june_slightly_pessimistic.1590178217.34
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 22 16:10 daily_contacts_june_slightly_pessimistic_testing.1590178217.34
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 22 16:10 daily_contacts_june_slightly_optimistic.1590178217.33
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 22 16:10 daily_contacts_june_realistic.1590178217.34
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 22 16:10 daily_contacts_june_realistic_testing.1590178217.34
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 22 16:10 daily_contacts_june_slightly_optimistic_testing.1590178217.33
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 22 16:10 mild_self_reporting_june_slightly_optimistic_testing.1590178217.33
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 22 16:10 mild_self_reporting_june_slightly_pessimistic_testing.1590178217.33
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 22 16:10 mild_self_reporting_june_realistic.1590178217.34
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 22 16:10 mild_self_reporting_june_slightly_optimistic.1590178217.34
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 22 16:10 mild_self_reporting_june_realistic_testing.1590178217.34
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 22 16:10 mild_self_reporting_june_slightly_pessimistic.1590178217.33
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 prevalence_june_slightly_pessimistic.1590178217.34
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 prevalence_june_slightly_pessimistic_testing.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 severe_self_reporting_june_slightly_optimistic_testing.1590178217.33
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 contact_recall_june_realistic.1590178217.33
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 prevalence_june_realistic.1590178217.33
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 contact_recall_june_realistic_testing.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 exposed_infection_p_june_realistic_testing.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 severe_self_reporting_june_slightly_optimistic.1590178217.34
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 contact_recall_june_slightly_optimistic_testing.1590178217.33
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 exposed_infection_p_june_slightly_pessimistic.1590178217.33
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 prevalence_june_slightly_optimistic.1590178217.34
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 prevalence_june_slightly_optimistic_testing.1590178217.33
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 contact_recall_june_slightly_optimistic.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 exposed_infection_p_june_slightly_optimistic.1590178217.34
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 prevalence_june_realistic_testing.1590178217.34
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 contact_recall_june_slightly_pessimistic.1590178217.33
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 22 16:10 contact_recall_june_slightly_pessimistic_testing.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 exposed_infection_p_june_realistic.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 severe_self_reporting_june_realistic.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 exposed_infection_p_june_slightly_optimistic_testing.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 severe_self_reporting_june_realistic_testing.1590178217.34
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 severe_self_reporting_june_slightly_pessimistic_testing.1590178217.33
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 severe_self_reporting_june_slightly_pessimistic.1590178217.33
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 22 16:10 contact_delay_june_realistic.1590178217.34
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 22 16:10 contact_delay_june_realistic_testing.1590178217.33
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 22 16:10 contact_delay_june_slightly_optimistic.1590178217.33
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 22 16:10 exposed_infection_p_june_slightly_pessimistic_testing.1590178217.33
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 22 16:10 contact_delay_june_slightly_pessimistic_testing.1590178217.33
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 22 16:10 contact_delay_june_slightly_optimistic_testing.1590178217.33
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 22 16:10 contact_delay_june_slightly_pessimistic.1590178217.33""".split('\n')
sim_dirs = [ls_output.split(' ')[-1] for ls_output in sim_dirs_ls_output]
for d in sim_dirs:
    print(d)
# Out:
# daily_contacts_june_slightly_pessimistic.1590178217.34
# daily_contacts_june_slightly_pessimistic_testing.1590178217.34
# daily_contacts_june_slightly_optimistic.1590178217.33
# daily_contacts_june_realistic.1590178217.34
# daily_contacts_june_realistic_testing.1590178217.34
# daily_contacts_june_slightly_optimistic_testing.1590178217.33
# mild_self_reporting_june_slightly_optimistic_testing.1590178217.33
# mild_self_reporting_june_slightly_pessimistic_testing.1590178217.33
# mild_self_reporting_june_realistic.1590178217.34
# mild_self_reporting_june_slightly_optimistic.1590178217.34
# mild_self_reporting_june_realistic_testing.1590178217.34
# mild_self_reporting_june_slightly_pessimistic.1590178217.33
# prevalence_june_slightly_pessimistic.1590178217.34
# prevalence_june_slightly_pessimistic_testing.1590178217.34
# severe_self_reporting_june_slightly_optimistic_testing.1590178217.33
# contact_recall_june_realistic.1590178217.33
# prevalence_june_realistic.1590178217.33
# ...

# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/src/simulations_v2")

from analysis_helpers import poisson_waiting_function, \
                            run_multiple_trajectories, \
                            plot_aip_vs_t, \
                            plot_cip_vs_t, \
                            run_sensitivity_sims, \
                            extract_cips, \
                            load_sim_dir

# %%
sim_results = {}
for d in sim_dirs:
    if 'june_slightly_pessimistic_testing' in d:
        label = 'june_slightly_pessimistic_testing'
    elif 'june_slightly_optimistic_testing' in d:
        label = 'fall_slightly_optimistic_testing'
    elif 'june_realistic_testing' in d:
        label = 'june_realistic_testing'
    elif 'june_slightly_pessimistic' in d:
        label = 'june_slightly_pessimistic'
    elif 'june_slightly_optimistic' in d:
        label = 'june_slightly_optimistic'
    elif 'june_realistic' in d:
        label = 'june_realistic'
    else:
        print("could not find label for {}".format(d))
        label = 'unlabeled'
    
    sublabel = d.split('_' + label)[0]
    
    if label not in sim_results:
        sim_results[label] = {}
    
    sim_results[label][sublabel] = load_sim_dir("/nfs01/covid_sims/" + d, verbose=False)
    print("done loading {}".format(d))
# Out:
# done loading daily_contacts_june_slightly_pessimistic.1590178217.34
# done loading daily_contacts_june_slightly_pessimistic_testing.1590178217.34
# done loading daily_contacts_june_slightly_optimistic.1590178217.33
# done loading daily_contacts_june_realistic.1590178217.34
# done loading daily_contacts_june_realistic_testing.1590178217.34
# done loading daily_contacts_june_slightly_optimistic_testing.1590178217.33
# done loading mild_self_reporting_june_slightly_optimistic_testing.1590178217.33
# done loading mild_self_reporting_june_slightly_pessimistic_testing.1590178217.33
# done loading mild_self_reporting_june_realistic.1590178217.34
# done loading mild_self_reporting_june_slightly_optimistic.1590178217.34
# done loading mild_self_reporting_june_realistic_testing.1590178217.34
# done loading mild_self_reporting_june_slightly_pessimistic.1590178217.33
# done loading prevalence_june_slightly_pessimistic.1590178217.34
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import ticker
# %matplotlib inline
def extract_severities(dfs):
    severities = []
    for df in dfs:
        all_cols = set(df.columns)
        new_cols = set(['cumulative_mild', 
                        'cumulative_severe', 
                        'severity_0', 
                        'severity_1', 
                        'severity_2', 
                        'severity_3'])
        main_cols = all_cols - new_cols
        subdf = df[list(main_cols)]
        popsize = sum(subdf.iloc[0])
        
        subdf = df[['severity_2', 'severity_3']]
        severe = sum(subdf.iloc[subdf.shape[0]-1])
        
        severities.append(100 * severe / popsize)
    return severities
def average_cumulative_severe(dfs):
    severities = []
    for df in dfs:
        all_cols = set(df.columns)
        new_cols = set(['cumulative_mild', 
                        'cumulative_severe', 
                        'severity_0', 
                        'severity_1', 
                        'severity_2', 
                        'severity_3'])
        main_cols = all_cols - new_cols
        subdf = df[list(main_cols)]
        popsize = sum(subdf.iloc[0])
        
        subdf = df[['severity_2', 'severity_3']]
        severe = sum(subdf.iloc[subdf.shape[0]-1])
        
        severities.append(100 * severe / popsize)
    return np.mean(severities)

def avg_cum_severe_quantile(dfs, q_low, q_high):
    severities = extract_severities(dfs)
    return np.quantile(severities, q_low), np.mean(severities), np.quantile(severities, q_high)

def cum_severe_quantiles(dfs, q_low, q_high):
    severities = extract_severities(dfs)
    return np.quantile(severities, q_low), np.quantile(severities, 0.5), np.quantile(severities, q_high)

def plot_many_dfs(sim_output_dict, yaxisfn, ylabel="", xlabel="", title="", figsize=(10,6)):
    plt.figure(figsize=figsize)
    for sim_label, sim_output in sim_output_dict.items():
        xs = []
        ys = []
        for sim_parameter_name, dfs in sim_output.items():
            # compute x-value assuming that sim_param_name is of form 'varied_param_name.value'
            param_val = float('.'.join(sim_parameter_name.split('.')[1:]))
            xs.append(param_val)
            # yaxisfn is a function that takes in a list of trajectory dataframes and
            # produces an output metric
            ys.append(yaxisfn(dfs))
        plt.plot(xs, ys, marker='o', label=sim_label)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend(loc='best')
    plt.show()


def truncate(val, y_min, y_max):
    return max(min(val, y_max), y_min)
    
def plot_many_dfs_quantiles(sim_output_dict, yaxisfn, normalize_x_axis, x_log_scale=False, 
                            y_log_scale=False,
                            q_low=0.05, q_high=0.95, 
                            y_min = 0, y_max = 5,
                            ylabel="", xlabel="", title="", figsize=(10,6), alpha=0.1, color=None, savefig_name = None):
    # assn: yaxisfn(dfs) returns a tuple (q_low_val, avg, q_high_val)
    epsilon=1e-6
    plt.figure(figsize=figsize)
    if x_log_scale:
        plt.xscale("log")
    if y_log_scale:
        plt.yscale("log")
        #_, _, ymin, _ = plt.axis()
        #plt.ylim(bottom=max(1e-2, ymin))
    else:
        plt.ylim(y_min, y_max)
    
    for sim_label, sim_output in sim_output_dict.items():
        xs = []
        ys = []
        q_low_vals = []
        q_high_vals = []
        for sim_parameter_name, dfs in sim_output.items():
            # compute x-value assuming that sim_param_name is of form 'varied_param_name.value'
            param_val = float('.'.join(sim_parameter_name.split('.')[1:]))
            if normalize_x_axis:
                xs.append(param_val * 100)
            else:
                xs.append(param_val)
            # yaxisfn is a function that takes in a list of trajectory dataframes and
            # produces an output metric
            q_low_val, avg, q_high_val = yaxisfn(dfs, q_low, q_high)
            if not y_log_scale:
                ys.append(truncate(avg, y_min, y_max))
                q_low_vals.append(truncate(q_low_val, y_min, y_max))
                q_high_vals.append(truncate(q_high_val, y_min, y_max))
            else:
                ys.append(avg + epsilon)
                q_low_vals.append(q_low_val + epsilon)
                q_high_vals.append(q_high_val + epsilon)
        if color == None:
            plt.plot(xs, ys, marker='o', label=sim_label)
            plt.fill_between(xs, q_low_vals, q_high_vals, alpha=alpha)
        else:
            plt.plot(xs, ys, marker='o', label=sim_label, color=color)
            plt.fill_between(xs, q_low_vals, q_high_vals, alpha=alpha, color=color)
    
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend(loc='best')
    if savefig_name:
        plt.savefig("/nfs01/covid_figs/" + savefig_name + ".pdf")
    
    
    
    plt.show()

# %%
sim_results.keys()
# Out:
# dict_keys(['june_slightly_pessimistic', 'june_slightly_pessimistic_testing', 'june_slightly_optimistic', 'june_realistic', 'june_realistic_testing', 'fall_slightly_optimistic_testing'])

# %%
sim_results['june_realistic'].keys()
# Out:
# dict_keys(['daily_contacts', 'mild_self_reporting', 'contact_recall', 'prevalence', 'exposed_infection_p', 'severe_self_reporting', 'contact_delay'])

# %%
main_labels = sim_results.keys()
sub_labels = sim_results['june_realistic'].keys()

# %%
plot_labels = {
    'daily_contacts': 'Average Contacts per Person per Day',
    'severe_self_reporting': 'Daily Symptomatic Self-Reporting Likelihoo (%)',
    'prevalence': 'Initial Prevalence (% of Total Population)',
    'mild_self_reporting': 'Daily Asymptomatic Self-Reporting Likelihood(%)',
    'exposed_infection_p': 'Transmission Likelihood per Contact (%)',
    'contact_recall': 'Percentage of Contacts Recalled in Contact Trace (%)',
    'contact_delay': 'Contact Trace Delay (Days)'
}

normalize_params = {
    'daily_contacts': False,
    'severe_self_reporting': True,
    'prevalence': True,
    'mild_self_reporting': True,
    'exposed_infection_p': True,
    'contact_recall': True,
    'contact_delay': False
}

plot_log_scale = {
    'daily_contacts': False,
    'severe_self_reporting': False,
    'prevalence': True,
    'mild_self_reporting': False,
    'exposed_infection_p': False,
    'contact_recall': False,
    'contact_delay': False    
}

# %% [markdown]
# # make plots for 'realistic' parameters

# %%
no_testing_results = sim_results['june_realistic']
testing_results = sim_results['june_realistic_testing']

for sublabel in sub_labels:
    
    plot_many_dfs_quantiles({'Without Testing': no_testing_results[sublabel], 
                             'With Testing': testing_results[sublabel]}, 
                            cum_severe_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Hospitalized",
                     title="Realistic Parameters: Hospitalization Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.2, y_min = 0, y_max=5, y_log_scale=True)

# %% [markdown]
# # make plots for 'slightly optimistic' parameters

# %%
sim_results['fall_slightly_optimistic_testing'].keys()
# Out:
# dict_keys(['daily_contacts_june_slightly_optimistic_testing.1590178217.33', 'mild_self_reporting_june_slightly_optimistic_testing.1590178217.33', 'severe_self_reporting_june_slightly_optimistic_testing.1590178217.33', 'contact_recall_june_slightly_optimistic_testing.1590178217.33', 'prevalence_june_slightly_optimistic_testing.1590178217.33', 'exposed_infection_p_june_slightly_optimistic_testing.1590178217.34', 'contact_delay_june_slightly_optimistic_testing.1590178217.33'])

# %%
no_testing_results = sim_results['june_slightly_optimistic']
testing_results = sim_results['fall_slightly_optimistic_testing']

for sublabel in sub_labels:
    
    plot_many_dfs_quantiles({'Without Testing': no_testing_results[sublabel], 
                             'With Testing': testing_results[sublabel]}, 
                            cum_severe_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Hospitalized",
                     title="Optimistic Parameters: Hospitalization Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.2, y_min = 0, y_max=5, y_log_scale=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-2e2891789b91> in <module>()
#       5
#       6     plot_many_dfs_quantiles({'Without Testing': no_testing_results[sublabel],
# ----> 7                              'With Testing': testing_results[sublabel]},
#       8                             cum_severe_quantiles,
#       9                             normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
#
# KeyError: 'daily_contacts'

# %% [markdown]
# # and finally, plots for 'slightly pessimistic' parameters

# %%
no_testing_results = sim_results['june_slightly_pessimistic']
testing_results = sim_results['june_slightly_pessimistic_testing']

for sublabel in sub_labels:
    
    plot_many_dfs_quantiles({'Without Testing': no_testing_results[sublabel], 
                             'With Testing': testing_results[sublabel]}, 
                            cum_severe_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Hospitalized",
                     title="Pessimistic Parameters: Hospitalization Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.2, y_min = 0, y_max=5, y_log_scale=True)
