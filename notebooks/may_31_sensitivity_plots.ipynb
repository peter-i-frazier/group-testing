# %%
dirs_ls_output = """1590952179-fall-nominal-withtest-contact_tracing_isolations
drwxrwxr-x  20 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-withtest-severe_symptoms_daily_self_report_p
drwxrwxr-x  20 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-june-nominal-notest-severe_symptoms_daily_self_report_p
drwxrwxr-x  23 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-notest-contact_tracing_isolations
drwxrwxr-x  20 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-notest-severe_symptoms_daily_self_report_p
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-june-nominal-notest-expected_contacts_per_day
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-notest-expected_contacts_per_day
drwxrwxr-x  18 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-june-nominal-notest-contact_tracing_isolations
drwxrwxr-x  19 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-withtest-expected_contacts_per_day
drwxrwxr-x  15 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-withtest-asymptomatic_p
drwxrwxr-x  17 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-june-nominal-notest-initial_ID_prevalence
drwxrwxr-x  17 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-withtest-initial_ID_prevalence
drwxrwxr-x  16 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-june-nominal-notest-mild_symptoms_daily_self_report_p
drwxrwxr-x  15 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-june-nominal-notest-asymptomatic_p
drwxrwxr-x  15 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-notest-asymptomatic_p
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-optimistic-withtest-test_protocol_QFNR
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-withtest-test_population_fraction
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-june-nominal-notest-exposed_infection_p
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-notest-exposed_infection_p
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-withtest-exposed_infection_p
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-optimistic-withtest-test_population_fraction
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 31 15:09 1590952179-fall-nominal-withtest-contact_tracing_delay
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-nominal-withtest-test_protocol_QFNR
drwxrwxr-x  13 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-pessimistic-withtest-test_protocol_QFNR
drwxrwxr-x  12 jmc678 pug-jmc678  4096 May 31 15:09 1590952179-fall-pessimistic-withtest-test_population_fraction
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 31 15:09 1590952179-fall-nominal-notest-contact_tracing_delay
drwxrwxr-x  10 jmc678 pug-jmc678   290 May 31 15:09 1590952179-june-nominal-notest-contact_tracing_delay
drwxrwxr-x   3 jmc678 pug-jmc678    57 May 31 15:09 1590952179-fall-nominal-withtest-mild_symptoms_daily_self_report_p
drwxrwxr-x   3 jmc678 pug-jmc678    57 May 31 15:09 1590952179-fall-optimistic-notest-mild_symptoms_daily_self_report_p
drwxrwxr-x   3 jmc678 pug-jmc678    57 May 31 15:09 1590952179-fall-pessimistic-notest-mild_symptoms_daily_self_report_p
drwxrwxr-x   3 jmc678 pug-jmc678    57 May 31 15:09 1590952179-fall-nominal-notest-mild_symptoms_daily_self_report_p
drwxrwxr-x   3 jmc678 pug-jmc678    57 May 31 15:09 1590952179-fall-optimistic-withtest-mild_symptoms_daily_self_report_p
drwxrwxr-x   3 jmc678 pug-jmc678    57 May 31 15:09 1590952179-fall-pessimistic-withtest-mild_symptoms_daily_self_report_p""".split('\n')
sim_dirs = [ls_output.split(' ')[-1] for ls_output in dirs_ls_output]
for d in sim_dirs:
    print(d)
# Out:
# 1590952179-fall-nominal-withtest-contact_tracing_isolations
# 1590952179-fall-nominal-withtest-severe_symptoms_daily_self_report_p
# 1590952179-june-nominal-notest-severe_symptoms_daily_self_report_p
# 1590952179-fall-nominal-notest-contact_tracing_isolations
# 1590952179-fall-nominal-notest-severe_symptoms_daily_self_report_p
# 1590952179-june-nominal-notest-expected_contacts_per_day
# 1590952179-fall-nominal-notest-expected_contacts_per_day
# 1590952179-june-nominal-notest-contact_tracing_isolations
# 1590952179-fall-nominal-withtest-expected_contacts_per_day
# 1590952179-fall-nominal-withtest-asymptomatic_p
# 1590952179-june-nominal-notest-initial_ID_prevalence
# 1590952179-fall-nominal-withtest-initial_ID_prevalence
# 1590952179-june-nominal-notest-mild_symptoms_daily_self_report_p
# 1590952179-june-nominal-notest-asymptomatic_p
# 1590952179-fall-nominal-notest-asymptomatic_p
# 1590952179-fall-optimistic-withtest-test_protocol_QFNR
# 1590952179-fall-nominal-withtest-test_population_fraction
# 1590952179-june-nominal-notest-exposed_infection_p
# 1590952179-fall-nominal-notest-exposed_infection_p
# 1590952179-fall-nominal-withtest-exposed_infection_p
# 1590952179-fall-optimistic-withtest-test_population_fraction
# 1590952179-fall-nominal-withtest-contact_tracing_delay
# 1590952179-fall-nominal-withtest-test_protocol_QFNR
# 1590952179-fall-pessimistic-withtest-test_protocol_QFNR
# 1590952179-fall-pessimistic-withtest-test_population_fraction
# 1590952179-fall-nominal-notest-contact_tracing_delay
# 1590952179-june-nominal-notest-contact_tracing_delay
# 1590952179-fall-nominal-withtest-mild_symptoms_daily_self_report_p
# 1590952179-fall-optimistic-notest-mild_symptoms_daily_self_report_p
# 1590952179-fall-pessimistic-notest-mild_symptoms_daily_self_report_p
# 1590952179-fall-nominal-notest-mild_symptoms_daily_self_report_p
# 1590952179-fall-optimistic-withtest-mild_symptoms_daily_self_report_p
# 1590952179-fall-pessimistic-withtest-mild_symptoms_daily_self_report_p

# %%
import sys
import os
import numpy as np
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path + "/src/simulations_v2")

from analysis_helpers import poisson_waiting_function, \
                            run_multiple_trajectories, \
                            plot_aip_vs_t, \
                            plot_cip_vs_t, \
                            run_sensitivity_sims, \
                            extract_cips, \
                            load_sim_dir
sim_results = {}
for d in sim_dirs:
    parts = d.split('-')
    when = parts[1]
    assn = parts[2]
    tested = parts[3]
    var = parts[4]
    
    if var not in sim_results:
        sim_results[var] = {}
    
    sim_results[var][(when, assn, tested)] = load_sim_dir("/nfs01/covid_sims/" + d, verbose=False)
    print("done loading {}".format(d))
# Out:
# done loading 1590952179-fall-nominal-withtest-contact_tracing_isolations
# done loading 1590952179-fall-nominal-withtest-severe_symptoms_daily_self_report_p
# done loading 1590952179-june-nominal-notest-severe_symptoms_daily_self_report_p
# done loading 1590952179-fall-nominal-notest-contact_tracing_isolations
# done loading 1590952179-fall-nominal-notest-severe_symptoms_daily_self_report_p
# done loading 1590952179-june-nominal-notest-expected_contacts_per_day
# done loading 1590952179-fall-nominal-notest-expected_contacts_per_day
# done loading 1590952179-june-nominal-notest-contact_tracing_isolations
# done loading 1590952179-fall-nominal-withtest-expected_contacts_per_day
# done loading 1590952179-fall-nominal-withtest-asymptomatic_p
# done loading 1590952179-june-nominal-notest-initial_ID_prevalence
# done loading 1590952179-fall-nominal-withtest-initial_ID_prevalence
# done loading 1590952179-june-nominal-notest-mild_symptoms_daily_self_report_p
# done loading 1590952179-june-nominal-notest-asymptomatic_p
# done loading 1590952179-fall-nominal-notest-asymptomatic_p
# done loading 1590952179-fall-optimistic-withtest-test_protocol_QFNR
# done loading 1590952179-fall-nominal-withtest-test_population_fraction
# done loading 1590952179-june-nominal-notest-exposed_infection_p
# done loading 1590952179-fall-nominal-notest-exposed_infection_p
# done loading 1590952179-fall-nominal-withtest-exposed_infection_p
# done loading 1590952179-fall-optimistic-withtest-test_population_fraction
# done loading 1590952179-fall-nominal-withtest-contact_tracing_delay
# done loading 1590952179-fall-nominal-withtest-test_protocol_QFNR
# done loading 1590952179-fall-pessimistic-withtest-test_protocol_QFNR
# done loading 1590952179-fall-pessimistic-withtest-test_population_fraction
# done loading 1590952179-fall-nominal-notest-contact_tracing_delay
# done loading 1590952179-june-nominal-notest-contact_tracing_delay
# done loading 1590952179-fall-nominal-withtest-mild_symptoms_daily_self_report_p
# done loading 1590952179-fall-optimistic-notest-mild_symptoms_daily_self_report_p
# done loading 1590952179-fall-pessimistic-notest-mild_symptoms_daily_self_report_p
# done loading 1590952179-fall-nominal-notest-mild_symptoms_daily_self_report_p
# done loading 1590952179-fall-optimistic-withtest-mild_symptoms_daily_self_report_p
# done loading 1590952179-fall-pessimistic-withtest-mild_symptoms_daily_self_report_p

# %%
import matplotlib.pyplot as plt
from matplotlib import ticker
# %matplotlib inline

def modify_tick_labels(labels, axis, use_int_labels):
    assert(axis in ['x', 'y'])
    new_labels = []
    for label in labels:
        txt = label.get_text()
        if txt == '':
            new_labels.append('')
        else: 
            if axis == 'x':
                val = label._x
            else:
                val = label._y
            
            if use_int_labels:
                newtxt = str(int(val))
            else:
                newtxt = str(float(val))
            
            new_labels.append(newtxt)
    return new_labels
            

def extract_severities(dfs, hospitalizations_only=True):
    severities = []
    for df in dfs:
        all_cols = set(df.columns)
        new_cols = set(['cumulative_mild', 
                        'cumulative_severe', 
                        'severity_0', 
                        'severity_1', 
                        'severity_2', 
                        'severity_3'])
        main_cols = all_cols - new_cols
        subdf = df[list(main_cols)]
        popsize = sum(subdf.iloc[0])
        
        if hospitalizations_only:
            subdf = df[['severity_2', 'severity_3']]
        else:
            subdf = df[['severity_0', 'severity_1', 'severity_2', 'severity_3']]

        severe = sum(subdf.iloc[subdf.shape[0]-1])
        
        severities.append(100 * severe / popsize)
    return severities
def average_cumulative_severe(dfs):
    severities = []
    for df in dfs:
        all_cols = set(df.columns)
        new_cols = set(['cumulative_mild', 
                        'cumulative_severe', 
                        'severity_0', 
                        'severity_1', 
                        'severity_2', 
                        'severity_3'])
        main_cols = all_cols - new_cols
        subdf = df[list(main_cols)]
        popsize = sum(subdf.iloc[0])
        
        subdf = df[['severity_2', 'severity_3']]
        severe = sum(subdf.iloc[subdf.shape[0]-1])
        
        severities.append(100 * severe / popsize)
    return np.mean(severities)

def avg_cum_severe_quantile(dfs, q_low, q_high):
    severities = extract_severities(dfs)
    return np.quantile(severities, q_low), np.mean(severities), np.quantile(severities, q_high)

def cum_severe_quantiles(dfs, q_low, q_high):
    severities = extract_severities(dfs)
    return np.quantile(severities, q_low), np.quantile(severities, 0.5), np.quantile(severities, q_high)

def cum_infection_quantiles(dfs, q_low, q_high):
    severities = extract_severities(dfs, hospitalizations_only=False)
    return np.quantile(severities, q_low), np.quantile(severities, 0.5), np.quantile(severities, q_high)

def plot_many_dfs(sim_output_dict, yaxisfn, ylabel="", xlabel="", title="", figsize=(10,6)):
    plt.figure(figsize=figsize)
    for sim_label, sim_output in sim_output_dict.items():
        xs = []
        ys = []
        for sim_parameter_name, dfs in sim_output.items():
            # compute x-value assuming that sim_param_name is of form 'varied_param_name.value'
            param_val = float('.'.join(sim_parameter_name.split('.')[1:]))
            xs.append(param_val)
            # yaxisfn is a function that takes in a list of trajectory dataframes and
            # produces an output metric
            ys.append(yaxisfn(dfs))
        plt.plot(xs, ys, marker='o', label=sim_label)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend(loc='best')
    plt.show()


def truncate(val, y_min, y_max):
    return max(min(val, y_max), y_min)
    
def plot_many_dfs_quantiles(sim_output_dict, yaxisfn, normalize_x_axis, x_log_scale=False, 
                            y_log_scale=False,
                            q_low=0.05, q_high=0.95, 
                            y_min = 0, y_max = 5,
                            ylabel="", xlabel="", title="", 
                            figsize=(10,6), alpha=0.1, color=None, savefig_name = None,
                            use_x_int_labels=False, use_y_int_labels=False):
    # assn: yaxisfn(dfs) returns a tuple (q_low_val, avg, q_high_val)
    epsilon=1e-6
    plt.figure(figsize=figsize)
    if x_log_scale:
        plt.xscale("log")
    if y_log_scale:
        plt.yscale("log")
        #_, _, ymin, _ = plt.axis()
        #plt.ylim(bottom=max(1e-2, ymin))
    else:
        plt.ylim(y_min, y_max)
    
    for sim_label, sim_output in sim_output_dict.items():
        xs = []
        ys = []
        q_low_vals = []
        q_high_vals = []
        for sim_parameter_name, dfs in sim_output.items():
            # compute x-value assuming that sim_param_name is of form 'varied_param_name-value'
            param_val = float(sim_parameter_name.split('-')[-1])
            if normalize_x_axis:
                xs.append(param_val * 100)
            else:
                xs.append(param_val)
            # yaxisfn is a function that takes in a list of trajectory dataframes and
            # produces an output metric
            q_low_val, avg, q_high_val = yaxisfn(dfs, q_low, q_high)
            if not y_log_scale:
                ys.append(truncate(avg, y_min, y_max))
                q_low_vals.append(truncate(q_low_val, y_min, y_max))
                q_high_vals.append(truncate(q_high_val, y_min, y_max))
            else:
                ys.append(avg + epsilon)
                q_low_vals.append(q_low_val + epsilon)
                q_high_vals.append(q_high_val + epsilon)
        
        sorted_points = sorted(zip(xs, ys, q_low_vals, q_high_vals), key=lambda x: x[0])
        xs = [p[0] for p in sorted_points]
        ys = [p[1] for p in sorted_points]
        q_low_vals = [p[2] for p in sorted_points]
        q_high_vals = [p[3] for p in sorted_points]
        
        if color == None:
            plt.plot(xs, ys, marker='o', label=sim_label)
            plt.fill_between(xs, q_low_vals, q_high_vals, alpha=alpha)
        else:
            plt.plot(xs, ys, marker='o', label=sim_label, color=color)
            plt.fill_between(xs, q_low_vals, q_high_vals, alpha=alpha, color=color)
    
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend(loc='best')
    
    
    
    plt.draw()
    
    ax = plt.gca()
    
    
    labels = ax.get_xmajorticklabels()
    new_labels = modify_tick_labels(labels, "x", use_x_int_labels)
    ax.set_xticklabels(new_labels)
    
    labels = ax.get_xminorticklabels()
    new_labels = modify_tick_labels(labels, "x", use_x_int_labels)
    ax.set_xticklabels(new_labels, minor=True)
    
    labels = ax.get_ymajorticklabels()
    new_labels = modify_tick_labels(labels, "y", use_y_int_labels)
    ax.set_yticklabels(new_labels)
    
    labels = ax.get_yminorticklabels()
    new_labels = modify_tick_labels(labels, "y", use_y_int_labels)
    ax.set_yticklabels(new_labels, minor=True)
    
    plt.tight_layout()
    if savefig_name:
        plt.savefig("/nfs01/covid_figs/" + savefig_name + ".pdf")
    plt.show()

# %%
plot_labels = {
    'daily_contacts': 'Average Contacts per Person per Day',
    'severe_self_reporting': 'Daily Symptomatic Self-Reporting Likelihood(%)',
    'prevalence': 'Initial Prevalence (% of Total Population)',
    'mild_self_reporting': 'Daily Asymptomatic Self-Reporting Likelihood(%)',
    'exposed_infection_p': 'Transmission Likelihood per Contact (%)',
    'contact_isolations': 'Isolations per Contact Trace',
    'contact_delay': 'Contact Trace Delay (Days)',
    'asymptomatic_p': 'Percentage of Cases Asymptomatic (%)'
}

normalize_params = {
    'daily_contacts': False,
    'severe_self_reporting': True,
    'prevalence': True,
    'mild_self_reporting': True,
    'exposed_infection_p': True,
    'contact_isolations': False,
    'contact_delay': False,
    'asymptomatic_p': True,
}

plot_log_scale = {
    'daily_contacts': True,
    'severe_self_reporting': False,
    'prevalence': True,
    'mild_self_reporting': False,
    'exposed_infection_p': True,
    'contact_isolations': False,
    'contact_delay': False,
    'asymptomatic_p': True
}

use_x_int_labels = {
    'daily_contacts': True,
    'severe_self_reporting': True,
    'prevalence': False,
    'mild_self_reporting': True,
    'exposed_infection_p': False,
    'contact_isolations': False,
    'contact_delay': True,
    'asymptomatic_p': False
}

# %%
key_mapping = {
    'contact_tracing_isolations': 'contact_isolations',
    'expected_contacts_per_day': 'daily_contacts',
    'mild_symptoms_daily_self_report_p': 'mild_self_reporting',
    'severe_symptoms_daily_self_report_p': 'severe_self_reporting',
    'initial_ID_prevalence': 'prevalence',
    'exposed_infection_p': 'exposed_infection_p',
    'asymptomatic_p': 'asymptomatic_p',
    'contact_tracing_delay': 'contact_delay'
}

# %%
for d in key_mapping.items():
    print(d)
# Out:
# ('contact_tracing_isolations', 'contact_isolations')
# ('expected_contacts_per_day', 'daily_contacts')
# ('mild_symptoms_daily_self_report_p', 'mild_self_reporting')
# ('severe_symptoms_daily_self_report_p', 'severe_self_reporting')
# ('initial_ID_prevalence', 'prevalence')
# ('exposed_infection_p', 'exposed_infection_p')
# ('asymptomatic_p', 'asymptomatic_p')
# ('contact_tracing_delay', 'contact_delay')

# %%
sim_results['contact_tracing_isolations'][('june', 'nominal', 'notest')] = load_sim_dir("/nfs01/covid_sims/1590972572-june-nominal-notest-contact_tracing_isolations")
# Out:
# done loading contact_tracing_isolations-0.1
# done loading contact_tracing_isolations-0.2
# done loading contact_tracing_isolations-0.3
# done loading contact_tracing_isolations-0.4
# done loading contact_tracing_isolations-0.5
# done loading contact_tracing_isolations-0.6
# done loading contact_tracing_isolations-0.7
# done loading contact_tracing_isolations-0.8
# done loading contact_tracing_isolations-0.9
# done loading contact_tracing_isolations-1
# done loading contact_tracing_isolations-1.25
# done loading contact_tracing_isolations-1.5
# done loading contact_tracing_isolations-1.75
# done loading contact_tracing_isolations-2.0
# done loading contact_tracing_isolations-2.25
# done loading contact_tracing_isolations-2.5
# done loading contact_tracing_isolations-2.75
# done loading contact_tracing_isolations-3
# done loading contact_tracing_isolations-3.5
# done loading contact_tracing_isolations-4
# done loading contact_tracing_isolations-4.5

# %%
sim_results['initial_ID_prevalence'][('fall', 'nominal', 'notest')] = load_sim_dir("/nfs01/covid_sims/1590972463-fall-nominal-notest-initial_ID_prevalence")
# Out:
# done loading initial_ID_prevalence-0.0001
# done loading initial_ID_prevalence-0.0002
# done loading initial_ID_prevalence-0.0003
# done loading initial_ID_prevalence-0.0004
# done loading initial_ID_prevalence-0.0005
# done loading initial_ID_prevalence-0.001
# done loading initial_ID_prevalence-0.002
# done loading initial_ID_prevalence-0.003
# done loading initial_ID_prevalence-0.004
# done loading initial_ID_prevalence-0.005
# done loading initial_ID_prevalence-0.01
# done loading initial_ID_prevalence-0.015
# done loading initial_ID_prevalence-0.02
# done loading initial_ID_prevalence-0.025
# done loading initial_ID_prevalence-0.03

# %%
for new_label, sublabel in key_mapping.items():
    
    
    plot_many_dfs_quantiles({'June Parameters': sim_results[new_label][('june', 'nominal', 'notest')], 
                             'Fall Parameters': sim_results[new_label][('fall', 'nominal', 'notest')],
                             'Fall Parameters With Testing': sim_results[new_label][('fall', 'nominal', 'withtest')]}, 
                            cum_severe_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Hospitalized",
                     title="Nominal Parameters: Hospitalization Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.1, y_min = 0, y_max=5, y_log_scale=True,
                               savefig_name="may_31_figs/hospitalization_{}".format(sublabel), 
                             use_x_int_labels=use_x_int_labels[sublabel])
    
    plot_many_dfs_quantiles({'June Parameters': sim_results[new_label][('june', 'nominal', 'notest')], 
                             'Fall Parameters': sim_results[new_label][('fall', 'nominal', 'notest')],
                             'Fall Parameters With Testing': sim_results[new_label][('fall', 'nominal', 'withtest')]}, 
                            cum_infection_quantiles,
                            normalize_params[sublabel], x_log_scale=plot_log_scale[sublabel],
                     xlabel=plot_labels[sublabel], ylabel="Percentage of Population Infected",
                     title="Nominal Parameters: Infection Percentage vs. {}".format(plot_labels[sublabel]), 
                               q_low=0.1, q_high=0.9, alpha=0.1, y_min = 0, y_max=5, y_log_scale=True,
                               savefig_name="may_31_figs/infection_{}".format(sublabel), 
                             use_x_int_labels=use_x_int_labels[sublabel])

# %%
new_label
# Out:
# 'initial_ID_prevalence'

# %%
def get_base_results(key):
    return sim_results['mild_symptoms_daily_self_report_p'][key]['mild_symptoms_daily_self_report_p-0']

# %%
severities = extract_severities(get_base_results(('fall', 'pessimistic', 'notest')), hospitalizations_only=False)
severities_testing = extract_severities(get_base_results(('fall', 'pessimistic', 'withtest')), hospitalizations_only=False)
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(10,6))
plt.hist(severities, alpha=0.7, normed=True, label="Without Asymptomatic Testing")
plt.hist(severities_testing, alpha=0.7, label="With Asymptomatic Testing", normed=True)
plt.title("Pessimistic Parameters: Infection Percentage with and without Testing")
plt.legend(loc='best')
plt.xlabel("Percentage of Population Infected")
plt.ylabel("Frequency")
plt.savefig("/nfs01/covid_figs/may_31_figs/pessimistic_infection_hist.pdf")

# %%
severities = extract_severities(get_base_results(('fall', 'pessimistic', 'notest')), hospitalizations_only=True)
severities_testing = extract_severities(get_base_results(('fall', 'pessimistic', 'withtest')), hospitalizations_only=True)
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(10,6))
plt.hist(severities, alpha=0.7, normed=True, label="Without Asymptomatic Testing")
plt.hist(severities_testing, alpha=0.7, label="With Asymptomatic Testing", normed=True)
plt.title("Pessimistic Parameters: Hospitalization Percentage with and without Testing")
plt.legend(loc='best')
plt.xlabel("Percentage of Population Hospitalized")
plt.ylabel("Frequency")
plt.savefig("/nfs01/covid_figs/may_31_figs/pessimistic_hospitalization_hist.pdf")

# %%
severities = extract_severities(get_base_results(('fall', 'optimistic', 'notest')), hospitalizations_only=False)
severities_testing = extract_severities(get_base_results(('fall', 'optimistic', 'withtest')), hospitalizations_only=False)
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(10,6))
plt.hist(severities, alpha=0.7, normed=True, label="Without Asymptomatic Testing")
plt.hist(severities_testing, alpha=0.7, label="With Asymptomatic Testing", normed=True)
plt.title("Optimistic Parameters: Infection Percentage with and without Testing")
plt.legend(loc='best')
plt.xlabel("Percentage of Population Infected")
plt.ylabel("Frequency")
plt.savefig("/nfs01/covid_figs/may_31_figs/optimistic_infection_hist.pdf")

# %%
severities = extract_severities(get_base_results(('fall', 'optimistic', 'notest')), hospitalizations_only=True)
severities_testing = extract_severities(get_base_results(('fall', 'optimistic', 'withtest')), hospitalizations_only=True)
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(10,6))
plt.hist(severities, alpha=0.7, normed=True, label="Without Asymptomatic Testing")
plt.hist(severities_testing, alpha=0.7, label="With Asymptomatic Testing", normed=True)
plt.title("Optimistic Parameters: Hospitalization Percentage with and without Testing")
plt.legend(loc='best')
plt.xlabel("Percentage of Population Hospitalized")
plt.ylabel("Frequency")
plt.savefig("/nfs01/covid_figs/may_31_figs/optimistic_hospitalization_hist.pdf")

# %%
severities = extract_severities(get_base_results(('fall', 'nominal', 'notest')), hospitalizations_only=False)
severities_testing = extract_severities(get_base_results(('fall', 'nominal', 'withtest')), hospitalizations_only=False)
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(10,6))
plt.hist(severities, alpha=0.7, normed=True, label="Without Asymptomatic Testing")
plt.hist(severities_testing, alpha=0.7, label="With Asymptomatic Testing", normed=True)
plt.title("Nominal Parameters: Infection Percentage with and without Testing")
plt.legend(loc='best')
plt.xlabel("Percentage of Population Infected")
plt.ylabel("Frequency")
plt.savefig("/nfs01/covid_figs/may_31_figs/nominal_infection_hist.pdf")

# %%
severities = extract_severities(get_base_results(('fall', 'nominal', 'notest')), hospitalizations_only=True)
severities_testing = extract_severities(get_base_results(('fall', 'nominal', 'withtest')), hospitalizations_only=True)
plt.rcParams.update({'font.size': 12})
plt.figure(figsize=(10,6))
plt.hist(severities, alpha=0.7, normed=True, label="Without Asymptomatic Testing")
plt.hist(severities_testing, alpha=0.7, label="With Asymptomatic Testing", normed=True)
plt.title("Nominal Parameters: Hospitalization Percentage with and without Testing")
plt.legend(loc='best')
plt.xlabel("Percentage of Population Hospitalized")
plt.ylabel("Frequency")
plt.savefig("/nfs01/covid_figs/may_31_figs/nominal_hospitalization_hist.pdf")

# %%
plot_many_dfs_quantiles({
    'Fall Nominal Parameters': sim_results['test_population_fraction'][('fall', 'nominal', 'withtest')], 
    'Fall Optimistic Parameters': sim_results['test_population_fraction'][('fall', 'optimistic', 'withtest')], 
    'Fall Pessimistic Parameters': sim_results['test_population_fraction'][('fall', 'pessimistic', 'withtest')], 
                     }, 
                            cum_severe_quantiles,
                            True, x_log_scale=False,
                     xlabel="Percentage of Population Tested Daily", ylabel="Percentage of Population Hospitalized",
                     title="Hospitalization Percentage vs. Percentage of Population Tested Daily", 
                               q_low=0.1, q_high=0.9, alpha=0.1, y_min = 0, y_max=5, y_log_scale=True,
                               savefig_name="may_31_figs/{}".format("hospitalization_testing_fraction"), 
                             use_x_int_labels=True)

plot_many_dfs_quantiles({
    'Fall Nominal Parameters': sim_results['test_population_fraction'][('fall', 'nominal', 'withtest')], 
    'Fall Optimistic Parameters': sim_results['test_population_fraction'][('fall', 'optimistic', 'withtest')], 
    'Fall Pessimistic Parameters': sim_results['test_population_fraction'][('fall', 'pessimistic', 'withtest')], }, 
                            cum_infection_quantiles,
                            True, x_log_scale=False,
                     xlabel="Percentage of Population Tested Daily", ylabel="Percentage of Population Infected",
                     title="Infection Percentage vs. Percentage of Population Tested Daily", 
                               q_low=0.1, q_high=0.9, alpha=0.1, y_min = 0, y_max=5, y_log_scale=True,
                               savefig_name="may_31_figs/{}".format("infection_testing_fraction"), 
                             use_x_int_labels=True)

# %%
plot_many_dfs_quantiles({ 'Fall Nominal Parameters': sim_results['test_protocol_QFNR'][('fall', 'nominal', 'withtest')], 
    'Fall Optimistic Parameters': sim_results['test_protocol_QFNR'][('fall', 'optimistic', 'withtest')], 
    'Fall Pessimistic Parameters': sim_results['test_protocol_QFNR'][('fall', 'pessimistic', 'withtest')],  }, 
                            cum_severe_quantiles,
                            True, x_log_scale=False,
                     xlabel="Testing False-Negative Rate", ylabel="Percentage of Population Hospitalized",
                     title="Hospitalization Percentage vs. Testing False-Negative Rate", 
                               q_low=0.1, q_high=0.9, alpha=0.1, y_min = 0, y_max=5, y_log_scale=True,
                               savefig_name="may_31_figs/{}".format("hospitalization_testing_qfnr"), 
                             use_x_int_labels=True)

plot_many_dfs_quantiles({'Fall Nominal Parameters': sim_results['test_protocol_QFNR'][('fall', 'nominal', 'withtest')], 
    'Fall Optimistic Parameters': sim_results['test_protocol_QFNR'][('fall', 'optimistic', 'withtest')], 
    'Fall Pessimistic Parameters': sim_results['test_protocol_QFNR'][('fall', 'pessimistic', 'withtest')],  }, 
                            cum_infection_quantiles,
                            True, x_log_scale=False,
                     xlabel="Testing False-Negative Rate", ylabel="Percentage of Population Infected",
                     title="Infection Percentage vs. Testing False-Negative Rate", 
                               q_low=0.1, q_high=0.9, alpha=0.1, y_min = 0, y_max=5, y_log_scale=True,
                               savefig_name="may_31_figs/{}".format("infection_testing_qfnr"), 
                             use_x_int_labels=True)
